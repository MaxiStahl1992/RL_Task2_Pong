# %% [markdown]
# # 1. Imports

# %%
import gymnasium as gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import random
import json
import pandas as pd

from stable_baselines3.common.evaluation import evaluate_policy

from huggingface_hub import notebook_login, upload_file

import torch
import torch.nn as nn
import torch.optim as optim

from collections import deque

# %%
notebook_login()
# Out:
# /Users/stahlma/anaconda3/envs/gymnasium/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:503: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# /Users/stahlma/anaconda3/envs/gymnasium/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:503: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)

# %% [markdown]
# # Global Configurations

# %%
# Set Seed
seed = 73

def set_global_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)

set_global_seeds(seed)

# %%
# Set device type
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Set Environment
num_envs = 8
env_id = "PongNoFrameskip-v4"
training_time_max = 32400 # 10800 - 3h, 21600 - 6h, 32400 - 9h

# %%
print(gym.envs.registry.get(env_id))
# Out:
# EnvSpec(id='PongNoFrameskip-v4', entry_point='shimmy.atari_env:AtariEnv', reward_threshold=None, nondeterministic=False, max_episode_steps=None, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'game': 'pong', 'obs_type': 'rgb', 'repeat_action_probability': 0.0, 'full_action_space': False, 'max_num_frames_per_episode': 108000, 'frameskip': 1}, namespace=None, name='PongNoFrameskip', version=4, additional_wrappers=(), vector_entry_point=None)

# %% [markdown]
# # Common Wrappers and Utilities

# %%
class ClipRewardEnv(gym.RewardWrapper):
    def __init__(self, env: gym.Env):
        super().__init__(env)
    
    def reward(self, reward: float) -> float:
        return np.sign(reward)

def AtariWrappers(env, frame_skip):
    env = gym.wrappers.AtariPreprocessing(
        env,
        noop_max=30,
        frame_skip=frame_skip,
        screen_size=84,
        terminal_on_life_loss=False,
        grayscale_obs=True,
        scale_obs=False,
    )
    env = gym.wrappers.FrameStack(env, 4)
    return env

def make_env(gym_id, seed, frame_skip, clip_rewards):
    def thunk():
        env = gym.make(gym_id, render_mode='rgb_array', frameskip=1)
        env = AtariWrappers(env, frame_skip)
        if clip_rewards:
            env = ClipRewardEnv(env)
        env.reset(seed=seed)
        env.action_space.seed(seed)
        return env
    return thunk

def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    nn.init.orthogonal_(layer.weight, std)
    nn.init.constant_(layer.bias, bias_const)
    return layer

class Config:
    def __init__(self, dictionary):
        for key, value in dictionary.items():
            setattr(self, key, value)

# %% [markdown]
# # PPO Implementation

# %% [markdown]
# ## Configurations

# %%
config_dict_ppo = {
    'device': 'cuda' if torch.cuda.is_available() else 'cpu',
    'gym_id': env_id,
    'total_timesteps': 1e7,
    'n_envs': 8,
    'n_steps': 128,
    'n_minibatches': 4,
    'update_epochs': 4,
    'frame_skip': 4,
    'hidden_size': 512,
    'learning_rate': 2.5e-4,
    'anneal_lr': False,
    'gamma': 0.99,
    'gae': True,
    'gae_lambda': 0.95,
    'clip_coef': 0.1,
    'norm_advantages': True,
    'clip_value_loss': True,
    'weight_value_loss': 0.5,
    'weight_ent_loss': 0.01,
    'max_grad_norm': 0.5,
    'time_limit': training_time_max, 
    'seed': seed
}

config_dict_ppo['batch_size'] = int(config_dict_ppo['n_envs'] * config_dict_ppo['n_steps'])
config_dict_ppo['minibatch_size'] = int(config_dict_ppo['batch_size'] // config_dict_ppo['n_minibatches'])

config_ppo = Config(config_dict_ppo)

# %% [markdown]
# ## Environment

# %%
# Create Vectorized Environments for PPO
envs_ppo = gym.vector.AsyncVectorEnv([
    make_env(config_ppo.gym_id, seed + i, config_ppo.frame_skip, clip_rewards=True) for i in range(config_ppo.n_envs)
])
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]

# %% [markdown]
# ## Neural Network

# %%
class PPONetwork(nn.Module):
    def __init__(self, input_shape, n_actions, hidden_size=512):
        super().__init__()
        self.base = nn.Sequential(
            layer_init(nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4)),
            nn.ReLU(),
            layer_init(nn.Conv2d(32, 64, kernel_size=4, stride=2)),
            nn.ReLU(),
            layer_init(nn.Conv2d(64, 64, kernel_size=3, stride=1)),
            nn.ReLU(),
            nn.Flatten(),
            layer_init(nn.Linear(64 * 7 * 7, hidden_size)),
            nn.ReLU()
        )
        self.actor = layer_init(nn.Linear(hidden_size, n_actions), std=0.01)
        self.critic = layer_init(nn.Linear(hidden_size, 1), std=1.0)

    def forward(self, x, action=None):
        x = x / 255.0  # Normalize pixel values
        x = self.base(x)
        logits = self.actor(x)
        value = self.critic(x)
        dist = torch.distributions.Categorical(logits=logits)
        if action is None:
            action = dist.sample()
        log_prob = dist.log_prob(action)
        entropy = dist.entropy()
        return action, log_prob, entropy, value

    def get_value(self, x):
        x = x / 255.0  # Normalize pixel values
        x = self.base(x)
        return self.critic(x)

# %% [markdown]
# ## Training

# %%
def train_ppo(config):
    device = torch.device(config.device)
    n_actions = envs_ppo.single_action_space.n
    input_shape = envs_ppo.single_observation_space.shape

    model = PPONetwork(input_shape, n_actions, config.hidden_size).to(device)
    optimizer = optim.Adam(model.parameters(), lr=config.learning_rate, eps=1e-5)

    # Initialize storage
    obs_shape = envs_ppo.single_observation_space.shape
    states = torch.zeros((config.n_steps, config.n_envs) + obs_shape).to(device)
    actions = torch.zeros((config.n_steps, config.n_envs)).to(device)
    rewards = torch.zeros((config.n_steps, config.n_envs)).to(device)
    dones = torch.zeros((config.n_steps, config.n_envs)).to(device)
    log_probs = torch.zeros((config.n_steps, config.n_envs)).to(device)
    values = torch.zeros((config.n_steps, config.n_envs)).to(device)

    # Metrics
    episode_rewards = []
    losses = []
    total_steps = 0
    total_episodes = 0

    # Counters for episodes and rewards since last print
    episodes_since_last_print = 0
    episode_rewards_since_last_print = []

    # Initialize time tracking
    start_time = time.time()
    episode_times = []  # Record the time when each episode ends
    loss_times = []     # Record the time when each loss is calculated
    threshold_times = {0: None, 10: None, 21: None}  # For convergence speed metric

    # Start training
    state, _ = envs_ppo.reset()
    state = torch.tensor(state).to(device)
    done = torch.zeros(config.n_envs).to(device)

    # Episode tracking
    episode_rewards_env = np.zeros(config.n_envs)
    episode_lengths_env = np.zeros(config.n_envs)

    while total_steps < config.total_timesteps:
        current_time = time.time()
        if current_time - start_time > config.time_limit:
            print("Time limit reached. Stopping training.")
            break

        # Anneal learning rate
        if config.anneal_lr:
            frac = 1.0 - (total_steps / config.total_timesteps)
            lr_now = frac * config.learning_rate
            optimizer.param_groups[0]['lr'] = lr_now

        # Collect rollout data
        for step in range(config.n_steps):
            with torch.no_grad():
                action, log_prob, _, value = model(state)
                values[step] = value.squeeze()
            actions[step] = action
            log_probs[step] = log_prob
            states[step] = state
            dones[step] = done

            next_state, reward, terminated, truncated, infos = envs_ppo.step(action.cpu().numpy())
            done = np.logical_or(terminated, truncated)
            rewards[step] = torch.tensor(reward).to(device)
            state = torch.tensor(next_state).to(device)
            done = torch.tensor(done).to(device)

            # Update episode rewards and lengths
            episode_rewards_env += reward
            episode_lengths_env += 1
            for idx, d in enumerate(done):
                if d:
                    # Append rewards to lists
                    episode_rewards.append(episode_rewards_env[idx])
                    episode_rewards_since_last_print.append(episode_rewards_env[idx])

                    # Record episode time
                    elapsed_time = time.time() - start_time
                    episode_times.append(elapsed_time)

                    # Check convergence thresholds
                    cumulative_reward = episode_rewards_env[idx]
                    for threshold in threshold_times:
                        if cumulative_reward >= threshold and threshold_times[threshold] is None:
                            threshold_times[threshold] = elapsed_time

                    # Reset per-environment rewards
                    episode_rewards_env[idx] = 0
                    total_episodes += 1
                    episodes_since_last_print += 1
                    episode_lengths_env[idx] = 0

            total_steps += config.n_envs

        # Compute advantages and returns
        with torch.no_grad():
            next_value = model.get_value(state).squeeze()
            advantages = torch.zeros_like(rewards).to(device)
            lastgaelam = 0
            for t in reversed(range(config.n_steps)):
                if t == config.n_steps - 1:
                    nextnonterminal = 1.0 - done.float()
                    next_values = next_value
                else:
                    nextnonterminal = 1.0 - dones[t + 1].float()
                    next_values = values[t + 1]
                delta = rewards[t] + config.gamma * next_values * nextnonterminal - values[t]
                advantages[t] = lastgaelam = delta + config.gamma * config.gae_lambda * nextnonterminal * lastgaelam
            returns = advantages + values

        # Flatten the batch
        b_states = states.reshape((-1,) + obs_shape)
        b_actions = actions.reshape(-1)
        b_log_probs = log_probs.reshape(-1)
        b_returns = returns.reshape(-1)
        b_advantages = advantages.reshape(-1)
        b_values = values.reshape(-1)

        # Normalize advantages
        if config.norm_advantages:
            b_advantages = (b_advantages - b_advantages.mean()) / (b_advantages.std() + 1e-8)

        # PPO Update
        inds = np.arange(config.batch_size)
        for epoch in range(config.update_epochs):
            np.random.shuffle(inds)
            for start in range(0, config.batch_size, config.minibatch_size):
                end = start + config.minibatch_size
                mb_inds = inds[start:end]

                mb_states = b_states[mb_inds]
                mb_actions = b_actions.long()[mb_inds]
                mb_old_log_probs = b_log_probs[mb_inds]
                mb_advantages = b_advantages[mb_inds]
                mb_returns = b_returns[mb_inds]
                mb_values = b_values[mb_inds]

                _, new_log_probs, entropy, new_values = model(mb_states, mb_actions)
                new_log_probs = new_log_probs.squeeze()
                entropy = entropy.squeeze()
                new_values = new_values.squeeze()

                # Policy loss
                log_ratio = new_log_probs - mb_old_log_probs
                ratio = log_ratio.exp()
                surr1 = ratio * mb_advantages
                surr2 = torch.clamp(ratio, 1.0 - config.clip_coef, 1.0 + config.clip_coef) * mb_advantages
                policy_loss = -torch.min(surr1, surr2).mean()

                # Value loss
                if config.clip_value_loss:
                    value_pred_clipped = mb_values + (new_values - mb_values).clamp(-config.clip_coef, config.clip_coef)
                    value_losses = (new_values - mb_returns).pow(2)
                    value_losses_clipped = (value_pred_clipped - mb_returns).pow(2)
                    value_loss = 0.5 * torch.max(value_losses, value_losses_clipped).mean()
                else:
                    value_loss = 0.5 * (new_values - mb_returns).pow(2).mean()

                # Entropy loss
                entropy_loss = entropy.mean()

                # Total loss
                loss = policy_loss + config.weight_value_loss * value_loss - config.weight_ent_loss * entropy_loss
                losses.append(loss.item())

                # Record time at loss calculation
                loss_times.append(time.time() - start_time)

                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(model.parameters(), config.max_grad_norm)
                optimizer.step()

        # Print progress
        if total_steps % (config.n_envs * 10) == 0:
            if len(episode_rewards) > 0:
                mean_reward = np.mean(episode_rewards[-10:]) if len(episode_rewards) >= 10 else np.mean(episode_rewards)
                mean_reward_last_episodes = np.mean(episode_rewards_since_last_print) if episodes_since_last_print > 0 else 0
                print(f"Total Steps: {total_steps}, Episodes: {total_episodes}, "
                    f"Mean Reward total: {mean_reward:.2f}, Episodes since last print: {episodes_since_last_print}, "
                    f"Mean Reward Last Episodes: {mean_reward_last_episodes:.2f}")
                
                # Reset the counters
                episodes_since_last_print = 0
                episode_rewards_since_last_print = []
            else:
                print(f"Total Steps: {total_steps}, Episodes: {total_episodes} (No episodes completed yet)")

    total_training_time = time.time() - start_time
    total_episodes = len(episode_rewards)
    timesteps_per_episode = total_steps / total_episodes if total_episodes > 0 else 0
    print("Training complete!")
    print(f"Total training time: {total_training_time:.2f} seconds")
    envs_ppo.close()
    return model, episode_rewards, total_training_time, losses, total_steps, total_episodes, timesteps_per_episode, episode_times, loss_times, threshold_times

# %%
ppo_custom_model, ppo_custom_episode_rewards, ppo_custom_total_training_time, ppo_custom_losses, ppo_custom_total_steps, ppo_custom_total_episodes, ppo_custom_timesteps_per_episode, ppo_episode_times, ppo_loss_times, ppo_threshold_times = train_ppo(config_ppo)
# Out:
# Total Steps: 5120, Episodes: 0 (No episodes completed yet)
# Total Steps: 10240, Episodes: 8, Mean Reward total: -20.38, Episodes since last print: 8, Mean Reward Last Episodes: -20.38
# Total Steps: 15360, Episodes: 14, Mean Reward total: -20.40, Episodes since last print: 6, Mean Reward Last Episodes: -20.50
# Total Steps: 20480, Episodes: 17, Mean Reward total: -20.30, Episodes since last print: 3, Mean Reward Last Episodes: -20.33
# Total Steps: 25600, Episodes: 24, Mean Reward total: -20.00, Episodes since last print: 7, Mean Reward Last Episodes: -19.86
# Total Steps: 30720, Episodes: 30, Mean Reward total: -20.20, Episodes since last print: 6, Mean Reward Last Episodes: -20.50
# Total Steps: 35840, Episodes: 34, Mean Reward total: -20.30, Episodes since last print: 4, Mean Reward Last Episodes: -20.00
# Total Steps: 40960, Episodes: 41, Mean Reward total: -20.50, Episodes since last print: 7, Mean Reward Last Episodes: -20.57
# Total Steps: 46080, Episodes: 45, Mean Reward total: -20.60, Episodes since last print: 4, Mean Reward Last Episodes: -20.75
# Total Steps: 51200, Episodes: 53, Mean Reward total: -20.50, Episodes since last print: 8, Mean Reward Last Episodes: -20.38
# Total Steps: 56320, Episodes: 56, Mean Reward total: -20.30, Episodes since last print: 3, Mean Reward Last Episodes: -20.00
# Total Steps: 61440, Episodes: 61, Mean Reward total: -20.40, Episodes since last print: 5, Mean Reward Last Episodes: -20.60
# Total Steps: 66560, Episodes: 69, Mean Reward total: -20.40, Episodes since last print: 8, Mean Reward Last Episodes: -20.25
# Total Steps: 71680, Episodes: 74, Mean Reward total: -20.50, Episodes since last print: 5, Mean Reward Last Episodes: -20.40
# Total Steps: 76800, Episodes: 81, Mean Reward total: -20.70, Episodes since last print: 7, Mean Reward Last Episodes: -20.86
# Total Steps: 81920, Episodes: 85, Mean Reward total: -20.70, Episodes since last print: 4, Mean Reward Last Episodes: -20.50
# Total Steps: 87040, Episodes: 92, Mean Reward total: -20.30, Episodes since last print: 7, Mean Reward Last Episodes: -20.29
# Total Steps: 92160, Episodes: 97, Mean Reward total: -20.30, Episodes since last print: 5, Mean Reward Last Episodes: -20.40
# Total Steps: 97280, Episodes: 103, Mean Reward total: -20.40, Episodes since last print: 6, Mean Reward Last Episodes: -20.50
# Total Steps: 102400, Episodes: 110, Mean Reward total: -20.60, Episodes since last print: 7, Mean Reward Last Episodes: -20.71
# Total Steps: 107520, Episodes: 115, Mean Reward total: -20.50, Episodes since last print: 5, Mean Reward Last Episodes: -20.20
# Total Steps: 112640, Episodes: 121, Mean Reward total: -20.00, Episodes since last print: 6, Mean Reward Last Episodes: -20.00
# Total Steps: 117760, Episodes: 125, Mean Reward total: -20.40, Episodes since last print: 4, Mean Reward Last Episodes: -21.00
# Total Steps: 122880, Episodes: 132, Mean Reward total: -20.70, Episodes since last print: 7, Mean Reward Last Episodes: -20.57
# Total Steps: 128000, Episodes: 136, Mean Reward total: -20.50, Episodes since last print: 4, Mean Reward Last Episodes: -20.00
# Total Steps: 133120, Episodes: 141, Mean Reward total: -19.60, Episodes since last print: 5, Mean Reward Last Episodes: -19.00
# Total Steps: 138240, Episodes: 148, Mean Reward total: -20.00, Episodes since last print: 7, Mean Reward Last Episodes: -20.57
# Total Steps: 143360, Episodes: 154, Mean Reward total: -20.40, Episodes since last print: 6, Mean Reward Last Episodes: -20.33
# Total Steps: 148480, Episodes: 157, Mean Reward total: -20.50, Episodes since last print: 3, Mean Reward Last Episodes: -20.67
# Total Steps: 153600, Episodes: 165, Mean Reward total: -20.40, Episodes since last print: 8, Mean Reward Last Episodes: -20.38
# Total Steps: 158720, Episodes: 169, Mean Reward total: -20.50, Episodes since last print: 4, Mean Reward Last Episodes: -20.75
# Total Steps: 163840, Episodes: 176, Mean Reward total: -20.10, Episodes since last print: 7, Mean Reward Last Episodes: -19.86
# Total Steps: 168960, Episodes: 181, Mean Reward total: -20.30, Episodes since last print: 5, Mean Reward Last Episodes: -20.80
# Total Steps: 174080, Episodes: 189, Mean Reward total: -20.40, Episodes since last print: 8, Mean Reward Last Episodes: -20.25
# Total Steps: 179200, Episodes: 192, Mean Reward total: -20.10, Episodes since last print: 3, Mean Reward Last Episodes: -20.00
# Total Steps: 184320, Episodes: 198, Mean Reward total: -20.20, Episodes since last print: 6, Mean Reward Last Episodes: -20.67
# Total Steps: 189440, Episodes: 205, Mean Reward total: -20.50, Episodes since last print: 7, Mean Reward Last Episodes: -20.43
# Total Steps: 194560, Episodes: 212, Mean Reward total: -20.80, Episodes since last print: 7, Mean Reward Last Episodes: -20.71
# Total Steps: 199680, Episodes: 216, Mean Reward total: -20.60, Episodes since last print: 4, Mean Reward Last Episodes: -20.50
# Total Steps: 204800, Episodes: 222, Mean Reward total: -20.30, Episodes since last print: 6, Mean Reward Last Episodes: -20.17
# Total Steps: 209920, Episodes: 229, Mean Reward total: -20.60, Episodes since last print: 7, Mean Reward Last Episodes: -20.71
# Total Steps: 215040, Episodes: 233, Mean Reward total: -20.70, Episodes since last print: 4, Mean Reward Last Episodes: -20.75
# Total Steps: 220160, Episodes: 239, Mean Reward total: -20.30, Episodes since last print: 6, Mean Reward Last Episodes: -20.00
# Total Steps: 225280, Episodes: 243, Mean Reward total: -20.10, Episodes since last print: 4, Mean Reward Last Episodes: -20.25
# Total Steps: 230400, Episodes: 249, Mean Reward total: -20.10, Episodes since last print: 6, Mean Reward Last Episodes: -20.00
# Total Steps: 235520, Episodes: 255, Mean Reward total: -20.20, Episodes since last print: 6, Mean Reward Last Episodes: -20.33
# Total Steps: 240640, Episodes: 260, Mean Reward total: -20.40, Episodes since last print: 5, Mean Reward Last Episodes: -20.60
# Total Steps: 245760, Episodes: 264, Mean Reward total: -20.50, Episodes since last print: 4, Mean Reward Last Episodes: -20.50
# Total Steps: 250880, Episodes: 271, Mean Reward total: -20.40, Episodes since last print: 7, Mean Reward Last Episodes: -20.29
# Total Steps: 256000, Episodes: 275, Mean Reward total: -20.30, Episodes since last print: 4, Mean Reward Last Episodes: -20.50
# Total Steps: 261120, Episodes: 280, Mean Reward total: -20.10, Episodes since last print: 5, Mean Reward Last Episodes: -19.60
# Total Steps: 266240, Episodes: 286, Mean Reward total: -20.10, Episodes since last print: 6, Mean Reward Last Episodes: -20.67
# Total Steps: 271360, Episodes: 290, Mean Reward total: -20.70, Episodes since last print: 4, Mean Reward Last Episodes: -20.75
# Total Steps: 276480, Episodes: 297, Mean Reward total: -20.80, Episodes since last print: 7, Mean Reward Last Episodes: -20.71
# Total Steps: 281600, Episodes: 302, Mean Reward total: -20.90, Episodes since last print: 5, Mean Reward Last Episodes: -21.00
# Total Steps: 286720, Episodes: 305, Mean Reward total: -21.00, Episodes since last print: 3, Mean Reward Last Episodes: -21.00
# Total Steps: 291840, Episodes: 312, Mean Reward total: -20.40, Episodes since last print: 7, Mean Reward Last Episodes: -20.14
# Total Steps: 296960, Episodes: 318, Mean Reward total: -20.20, Episodes since last print: 6, Mean Reward Last Episodes: -20.33
# Total Steps: 302080, Episodes: 324, Mean Reward total: -20.20, Episodes since last print: 6, Mean Reward Last Episodes: -20.33
# Total Steps: 307200, Episodes: 327, Mean Reward total: -20.00, Episodes since last print: 3, Mean Reward Last Episodes: -19.33
# Total Steps: 312320, Episodes: 333, Mean Reward total: -19.80, Episodes since last print: 6, Mean Reward Last Episodes: -20.00
# Total Steps: 317440, Episodes: 339, Mean Reward total: -20.30, Episodes since last print: 6, Mean Reward Last Episodes: -20.33
# Total Steps: 322560, Episodes: 346, Mean Reward total: -20.40, Episodes since last print: 7, Mean Reward Last Episodes: -20.43
# Total Steps: 327680, Episodes: 349, Mean Reward total: -20.30, Episodes since last print: 3, Mean Reward Last Episodes: -20.00
# Total Steps: 332800, Episodes: 356, Mean Reward total: -20.50, Episodes since last print: 7, Mean Reward Last Episodes: -20.71
# Total Steps: 337920, Episodes: 363, Mean Reward total: -20.30, Episodes since last print: 7, Mean Reward Last Episodes: -20.29
# Total Steps: 343040, Episodes: 367, Mean Reward total: -20.60, Episodes since last print: 4, Mean Reward Last Episodes: -20.50
# Total Steps: 348160, Episodes: 372, Mean Reward total: -20.70, Episodes since last print: 5, Mean Reward Last Episodes: -20.80
# Total Steps: 353280, Episodes: 378, Mean Reward total: -20.70, Episodes since last print: 6, Mean Reward Last Episodes: -20.67
# Total Steps: 358400, Episodes: 384, Mean Reward total: -20.80, Episodes since last print: 6, Mean Reward Last Episodes: -21.00
# Total Steps: 363520, Episodes: 388, Mean Reward total: -20.40, Episodes since last print: 4, Mean Reward Last Episodes: -19.50
# Total Steps: 368640, Episodes: 393, Mean Reward total: -19.60, Episodes since last print: 5, Mean Reward Last Episodes: -19.40
# Total Steps: 373760, Episodes: 400, Mean Reward total: -20.10, Episodes since last print: 7, Mean Reward Last Episodes: -20.29
# Total Steps: 378880, Episodes: 404, Mean Reward total: -20.50, Episodes since last print: 4, Mean Reward Last Episodes: -21.00
# Total Steps: 384000, Episodes: 411, Mean Reward total: -20.80, Episodes since last print: 7, Mean Reward Last Episodes: -20.71
# Total Steps: 389120, Episodes: 416, Mean Reward total: -20.20, Episodes since last print: 5, Mean Reward Last Episodes: -19.80
# Total Steps: 394240, Episodes: 421, Mean Reward total: -19.90, Episodes since last print: 5, Mean Reward Last Episodes: -20.00
# Total Steps: 399360, Episodes: 427, Mean Reward total: -20.00, Episodes since last print: 6, Mean Reward Last Episodes: -20.17
# Total Steps: 404480, Episodes: 433, Mean Reward total: -20.70, Episodes since last print: 6, Mean Reward Last Episodes: -20.67
# Total Steps: 409600, Episodes: 437, Mean Reward total: -20.40, Episodes since last print: 4, Mean Reward Last Episodes: -20.00
# Total Steps: 414720, Episodes: 442, Mean Reward total: -20.00, Episodes since last print: 5, Mean Reward Last Episodes: -19.80
# Total Steps: 419840, Episodes: 449, Mean Reward total: -20.30, Episodes since last print: 7, Mean Reward Last Episodes: -20.14
# Total Steps: 424960, Episodes: 454, Mean Reward total: -19.70, Episodes since last print: 5, Mean Reward Last Episodes: -19.20
# Total Steps: 430080, Episodes: 457, Mean Reward total: -19.30, Episodes since last print: 3, Mean Reward Last Episodes: -19.33
# Total Steps: 435200, Episodes: 465, Mean Reward total: -20.00, Episodes since last print: 8, Mean Reward Last Episodes: -20.12
# Total Steps: 440320, Episodes: 470, Mean Reward total: -20.20, Episodes since last print: 5, Mean Reward Last Episodes: -20.40
# Total Steps: 445440, Episodes: 473, Mean Reward total: -20.10, Episodes since last print: 3, Mean Reward Last Episodes: -20.33
# Total Steps: 450560, Episodes: 481, Mean Reward total: -20.30, Episodes since last print: 8, Mean Reward Last Episodes: -20.38
# Total Steps: 455680, Episodes: 486, Mean Reward total: -20.20, Episodes since last print: 5, Mean Reward Last Episodes: -20.20
# Total Steps: 460800, Episodes: 490, Mean Reward total: -20.20, Episodes since last print: 4, Mean Reward Last Episodes: -20.50
# Total Steps: 465920, Episodes: 497, Mean Reward total: -20.70, Episodes since last print: 7, Mean Reward Last Episodes: -20.71
# Total Steps: 471040, Episodes: 504, Mean Reward total: -20.50, Episodes since last print: 7, Mean Reward Last Episodes: -20.29
# Total Steps: 476160, Episodes: 505, Mean Reward total: -20.40, Episodes since last print: 1, Mean Reward Last Episodes: -20.00
# Total Steps: 481280, Episodes: 513, Mean Reward total: -19.50, Episodes since last print: 8, Mean Reward Last Episodes: -19.25
# Total Steps: 486400, Episodes: 518, Mean Reward total: -19.70, Episodes since last print: 5, Mean Reward Last Episodes: -20.40
# Total Steps: 491520, Episodes: 521, Mean Reward total: -20.10, Episodes since last print: 3, Mean Reward Last Episodes: -20.67
# Total Steps: 496640, Episodes: 528, Mean Reward total: -20.30, Episodes since last print: 7, Mean Reward Last Episodes: -20.14
# Total Steps: 501760, Episodes: 533, Mean Reward total: -20.40, Episodes since last print: 5, Mean Reward Last Episodes: -20.60
# Total Steps: 506880, Episodes: 537, Mean Reward total: -20.30, Episodes since last print: 4, Mean Reward Last Episodes: -19.75
# Total Steps: 512000, Episodes: 541, Mean Reward total: -19.50, Episodes since last print: 4, Mean Reward Last Episodes: -19.00
# Total Steps: 517120, Episodes: 545, Mean Reward total: -19.30, Episodes since last print: 4, Mean Reward Last Episodes: -19.50
# Total Steps: 522240, Episodes: 552, Mean Reward total: -20.00, Episodes since last print: 7, Mean Reward Last Episodes: -20.14
# Total Steps: 527360, Episodes: 554, Mean Reward total: -20.10, Episodes since last print: 2, Mean Reward Last Episodes: -20.00
# Total Steps: 532480, Episodes: 561, Mean Reward total: -19.50, Episodes since last print: 7, Mean Reward Last Episodes: -19.29
# Total Steps: 537600, Episodes: 564, Mean Reward total: -19.40, Episodes since last print: 3, Mean Reward Last Episodes: -19.67
# Total Steps: 542720, Episodes: 569, Mean Reward total: -19.10, Episodes since last print: 5, Mean Reward Last Episodes: -18.60
# Total Steps: 547840, Episodes: 571, Mean Reward total: -19.10, Episodes since last print: 2, Mean Reward Last Episodes: -19.50
# Total Steps: 552960, Episodes: 577, Mean Reward total: -19.10, Episodes since last print: 6, Mean Reward Last Episodes: -19.50
# Total Steps: 558080, Episodes: 581, Mean Reward total: -19.60, Episodes since last print: 4, Mean Reward Last Episodes: -19.75
# Total Steps: 563200, Episodes: 586, Mean Reward total: -19.60, Episodes since last print: 5, Mean Reward Last Episodes: -19.40
# Total Steps: 568320, Episodes: 589, Mean Reward total: -19.40, Episodes since last print: 3, Mean Reward Last Episodes: -19.00
# Total Steps: 573440, Episodes: 594, Mean Reward total: -19.40, Episodes since last print: 5, Mean Reward Last Episodes: -19.80
# Total Steps: 578560, Episodes: 596, Mean Reward total: -19.70, Episodes since last print: 2, Mean Reward Last Episodes: -20.50
# Total Steps: 583680, Episodes: 603, Mean Reward total: -19.60, Episodes since last print: 7, Mean Reward Last Episodes: -19.43
# Total Steps: 588800, Episodes: 603, Mean Reward total: -19.60, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 593920, Episodes: 609, Mean Reward total: -19.00, Episodes since last print: 6, Mean Reward Last Episodes: -18.67
# Total Steps: 599040, Episodes: 611, Mean Reward total: -18.80, Episodes since last print: 2, Mean Reward Last Episodes: -19.00
# Total Steps: 604160, Episodes: 615, Mean Reward total: -18.90, Episodes since last print: 4, Mean Reward Last Episodes: -18.25
# Total Steps: 609280, Episodes: 619, Mean Reward total: -18.30, Episodes since last print: 4, Mean Reward Last Episodes: -18.00
# Total Steps: 614400, Episodes: 621, Mean Reward total: -18.60, Episodes since last print: 2, Mean Reward Last Episodes: -20.50
# Total Steps: 619520, Episodes: 625, Mean Reward total: -18.80, Episodes since last print: 4, Mean Reward Last Episodes: -18.75
# Total Steps: 624640, Episodes: 627, Mean Reward total: -18.90, Episodes since last print: 2, Mean Reward Last Episodes: -19.00
# Total Steps: 629760, Episodes: 629, Mean Reward total: -19.10, Episodes since last print: 2, Mean Reward Last Episodes: -18.50
# Total Steps: 634880, Episodes: 633, Mean Reward total: -18.60, Episodes since last print: 4, Mean Reward Last Episodes: -18.50
# Total Steps: 640000, Episodes: 634, Mean Reward total: -18.90, Episodes since last print: 1, Mean Reward Last Episodes: -20.00
# Total Steps: 645120, Episodes: 636, Mean Reward total: -18.80, Episodes since last print: 2, Mean Reward Last Episodes: -19.00
# Total Steps: 650240, Episodes: 641, Mean Reward total: -19.20, Episodes since last print: 5, Mean Reward Last Episodes: -19.60
# Total Steps: 655360, Episodes: 642, Mean Reward total: -19.20, Episodes since last print: 1, Mean Reward Last Episodes: -17.00
# Total Steps: 660480, Episodes: 643, Mean Reward total: -19.40, Episodes since last print: 1, Mean Reward Last Episodes: -21.00
# Total Steps: 665600, Episodes: 648, Mean Reward total: -17.60, Episodes since last print: 5, Mean Reward Last Episodes: -16.40
# Total Steps: 670720, Episodes: 650, Mean Reward total: -17.20, Episodes since last print: 2, Mean Reward Last Episodes: -16.00
# Total Steps: 675840, Episodes: 651, Mean Reward total: -16.70, Episodes since last print: 1, Mean Reward Last Episodes: -15.00
# Total Steps: 680960, Episodes: 654, Mean Reward total: -17.00, Episodes since last print: 3, Mean Reward Last Episodes: -19.33
# Total Steps: 686080, Episodes: 658, Mean Reward total: -17.80, Episodes since last print: 4, Mean Reward Last Episodes: -18.25
# Total Steps: 691200, Episodes: 658, Mean Reward total: -17.80, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 696320, Episodes: 660, Mean Reward total: -17.90, Episodes since last print: 2, Mean Reward Last Episodes: -16.50
# Total Steps: 701440, Episodes: 662, Mean Reward total: -18.10, Episodes since last print: 2, Mean Reward Last Episodes: -19.00
# Total Steps: 706560, Episodes: 666, Mean Reward total: -16.90, Episodes since last print: 4, Mean Reward Last Episodes: -16.00
# Total Steps: 711680, Episodes: 666, Mean Reward total: -16.90, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 716800, Episodes: 668, Mean Reward total: -17.50, Episodes since last print: 2, Mean Reward Last Episodes: -20.00
# Total Steps: 721920, Episodes: 672, Mean Reward total: -18.00, Episodes since last print: 4, Mean Reward Last Episodes: -19.00
# Total Steps: 727040, Episodes: 674, Mean Reward total: -17.70, Episodes since last print: 2, Mean Reward Last Episodes: -16.50
# Total Steps: 732160, Episodes: 675, Mean Reward total: -18.30, Episodes since last print: 1, Mean Reward Last Episodes: -21.00
# Total Steps: 737280, Episodes: 677, Mean Reward total: -18.60, Episodes since last print: 2, Mean Reward Last Episodes: -18.00
# Total Steps: 742400, Episodes: 680, Mean Reward total: -18.00, Episodes since last print: 3, Mean Reward Last Episodes: -17.67
# Total Steps: 747520, Episodes: 682, Mean Reward total: -18.20, Episodes since last print: 2, Mean Reward Last Episodes: -19.50
# Total Steps: 752640, Episodes: 683, Mean Reward total: -18.10, Episodes since last print: 1, Mean Reward Last Episodes: -16.00
# Total Steps: 757760, Episodes: 685, Mean Reward total: -18.10, Episodes since last print: 2, Mean Reward Last Episodes: -18.50
# Total Steps: 762880, Episodes: 686, Mean Reward total: -18.20, Episodes since last print: 1, Mean Reward Last Episodes: -17.00
# Total Steps: 768000, Episodes: 689, Mean Reward total: -17.30, Episodes since last print: 3, Mean Reward Last Episodes: -16.00
# Total Steps: 773120, Episodes: 692, Mean Reward total: -17.20, Episodes since last print: 3, Mean Reward Last Episodes: -18.00
# Total Steps: 778240, Episodes: 693, Mean Reward total: -17.00, Episodes since last print: 1, Mean Reward Last Episodes: -14.00
# Total Steps: 783360, Episodes: 694, Mean Reward total: -16.50, Episodes since last print: 1, Mean Reward Last Episodes: -14.00
# Total Steps: 788480, Episodes: 699, Mean Reward total: -17.00, Episodes since last print: 5, Mean Reward Last Episodes: -17.60
# Total Steps: 793600, Episodes: 700, Mean Reward total: -16.90, Episodes since last print: 1, Mean Reward Last Episodes: -14.00
# Total Steps: 798720, Episodes: 700, Mean Reward total: -16.90, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 803840, Episodes: 703, Mean Reward total: -16.40, Episodes since last print: 3, Mean Reward Last Episodes: -16.00
# Total Steps: 808960, Episodes: 706, Mean Reward total: -16.10, Episodes since last print: 3, Mean Reward Last Episodes: -15.67
# Total Steps: 814080, Episodes: 708, Mean Reward total: -15.80, Episodes since last print: 2, Mean Reward Last Episodes: -15.00
# Total Steps: 819200, Episodes: 709, Mean Reward total: -15.60, Episodes since last print: 1, Mean Reward Last Episodes: -17.00
# Total Steps: 824320, Episodes: 709, Mean Reward total: -15.60, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 829440, Episodes: 713, Mean Reward total: -16.10, Episodes since last print: 4, Mean Reward Last Episodes: -16.75
# Total Steps: 834560, Episodes: 715, Mean Reward total: -16.20, Episodes since last print: 2, Mean Reward Last Episodes: -16.00
# Total Steps: 839680, Episodes: 717, Mean Reward total: -16.40, Episodes since last print: 2, Mean Reward Last Episodes: -16.00
# Total Steps: 844800, Episodes: 717, Mean Reward total: -16.40, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 849920, Episodes: 722, Mean Reward total: -16.90, Episodes since last print: 5, Mean Reward Last Episodes: -18.00
# Total Steps: 855040, Episodes: 724, Mean Reward total: -17.40, Episodes since last print: 2, Mean Reward Last Episodes: -17.50
# Total Steps: 860160, Episodes: 725, Mean Reward total: -17.20, Episodes since last print: 1, Mean Reward Last Episodes: -15.00
# Total Steps: 865280, Episodes: 726, Mean Reward total: -17.20, Episodes since last print: 1, Mean Reward Last Episodes: -18.00
# Total Steps: 870400, Episodes: 730, Mean Reward total: -17.00, Episodes since last print: 4, Mean Reward Last Episodes: -16.25
# Total Steps: 875520, Episodes: 731, Mean Reward total: -16.80, Episodes since last print: 1, Mean Reward Last Episodes: -19.00
# Total Steps: 880640, Episodes: 733, Mean Reward total: -17.00, Episodes since last print: 2, Mean Reward Last Episodes: -17.00
# Total Steps: 885760, Episodes: 733, Mean Reward total: -17.00, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 890880, Episodes: 737, Mean Reward total: -18.00, Episodes since last print: 4, Mean Reward Last Episodes: -19.75
# Total Steps: 896000, Episodes: 738, Mean Reward total: -18.00, Episodes since last print: 1, Mean Reward Last Episodes: -16.00
# Total Steps: 901120, Episodes: 740, Mean Reward total: -17.50, Episodes since last print: 2, Mean Reward Last Episodes: -13.50
# Total Steps: 906240, Episodes: 741, Mean Reward total: -16.90, Episodes since last print: 1, Mean Reward Last Episodes: -13.00
# Total Steps: 911360, Episodes: 742, Mean Reward total: -17.40, Episodes since last print: 1, Mean Reward Last Episodes: -20.00
# Total Steps: 916480, Episodes: 744, Mean Reward total: -16.00, Episodes since last print: 2, Mean Reward Last Episodes: -13.00
# Total Steps: 921600, Episodes: 747, Mean Reward total: -14.00, Episodes since last print: 3, Mean Reward Last Episodes: -12.67
# Total Steps: 926720, Episodes: 749, Mean Reward total: -14.40, Episodes since last print: 2, Mean Reward Last Episodes: -17.50
# Total Steps: 931840, Episodes: 750, Mean Reward total: -14.30, Episodes since last print: 1, Mean Reward Last Episodes: -11.00
# Total Steps: 936960, Episodes: 750, Mean Reward total: -14.30, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 942080, Episodes: 754, Mean Reward total: -15.30, Episodes since last print: 4, Mean Reward Last Episodes: -17.25
# Total Steps: 947200, Episodes: 755, Mean Reward total: -15.50, Episodes since last print: 1, Mean Reward Last Episodes: -14.00
# Total Steps: 952320, Episodes: 758, Mean Reward total: -16.50, Episodes since last print: 3, Mean Reward Last Episodes: -18.33
# Total Steps: 957440, Episodes: 758, Mean Reward total: -16.50, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 962560, Episodes: 761, Mean Reward total: -17.20, Episodes since last print: 3, Mean Reward Last Episodes: -16.67
# Total Steps: 967680, Episodes: 761, Mean Reward total: -17.20, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 972800, Episodes: 763, Mean Reward total: -17.10, Episodes since last print: 2, Mean Reward Last Episodes: -18.50
# Total Steps: 977920, Episodes: 764, Mean Reward total: -17.30, Episodes since last print: 1, Mean Reward Last Episodes: -17.00
# Total Steps: 983040, Episodes: 766, Mean Reward total: -17.30, Episodes since last print: 2, Mean Reward Last Episodes: -15.50
# Total Steps: 988160, Episodes: 767, Mean Reward total: -16.90, Episodes since last print: 1, Mean Reward Last Episodes: -14.00
# Total Steps: 993280, Episodes: 768, Mean Reward total: -15.40, Episodes since last print: 1, Mean Reward Last Episodes: -5.00
# Total Steps: 998400, Episodes: 771, Mean Reward total: -14.30, Episodes since last print: 3, Mean Reward Last Episodes: -13.00
# Total Steps: 1003520, Episodes: 773, Mean Reward total: -13.30, Episodes since last print: 2, Mean Reward Last Episodes: -13.50
# Total Steps: 1008640, Episodes: 775, Mean Reward total: -12.50, Episodes since last print: 2, Mean Reward Last Episodes: -12.50
# Total Steps: 1013760, Episodes: 775, Mean Reward total: -12.50, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1018880, Episodes: 776, Mean Reward total: -12.50, Episodes since last print: 1, Mean Reward Last Episodes: -15.00
# Total Steps: 1024000, Episodes: 780, Mean Reward total: -13.90, Episodes since last print: 4, Mean Reward Last Episodes: -14.25
# Total Steps: 1029120, Episodes: 781, Mean Reward total: -12.80, Episodes since last print: 1, Mean Reward Last Episodes: -4.00
# Total Steps: 1034240, Episodes: 783, Mean Reward total: -13.30, Episodes since last print: 2, Mean Reward Last Episodes: -16.00
# Total Steps: 1039360, Episodes: 783, Mean Reward total: -13.30, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1044480, Episodes: 784, Mean Reward total: -13.10, Episodes since last print: 1, Mean Reward Last Episodes: -9.00
# Total Steps: 1049600, Episodes: 786, Mean Reward total: -12.90, Episodes since last print: 2, Mean Reward Last Episodes: -13.50
# Total Steps: 1054720, Episodes: 789, Mean Reward total: -10.50, Episodes since last print: 3, Mean Reward Last Episodes: -6.00
# Total Steps: 1059840, Episodes: 791, Mean Reward total: -10.40, Episodes since last print: 2, Mean Reward Last Episodes: -9.00
# Total Steps: 1064960, Episodes: 791, Mean Reward total: -10.40, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1070080, Episodes: 791, Mean Reward total: -10.40, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1075200, Episodes: 792, Mean Reward total: -9.00, Episodes since last print: 1, Mean Reward Last Episodes: -4.00
# Total Steps: 1080320, Episodes: 795, Mean Reward total: -6.30, Episodes since last print: 3, Mean Reward Last Episodes: -3.00
# Total Steps: 1085440, Episodes: 798, Mean Reward total: -7.80, Episodes since last print: 3, Mean Reward Last Episodes: -11.67
# Total Steps: 1090560, Episodes: 799, Mean Reward total: -7.40, Episodes since last print: 1, Mean Reward Last Episodes: -8.00
# Total Steps: 1095680, Episodes: 801, Mean Reward total: -1.70, Episodes since last print: 2, Mean Reward Last Episodes: 19.50
# Total Steps: 1100800, Episodes: 801, Mean Reward total: -1.70, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1105920, Episodes: 803, Mean Reward total: -0.90, Episodes since last print: 2, Mean Reward Last Episodes: -2.00
# Total Steps: 1111040, Episodes: 805, Mean Reward total: -3.50, Episodes since last print: 2, Mean Reward Last Episodes: -13.50
# Total Steps: 1116160, Episodes: 807, Mean Reward total: 0.70, Episodes since last print: 2, Mean Reward Last Episodes: 11.50
# Total Steps: 1121280, Episodes: 808, Mean Reward total: 1.40, Episodes since last print: 1, Mean Reward Last Episodes: -9.00
# Total Steps: 1126400, Episodes: 810, Mean Reward total: 1.70, Episodes since last print: 2, Mean Reward Last Episodes: 7.50
# Total Steps: 1131520, Episodes: 811, Mean Reward total: 1.50, Episodes since last print: 1, Mean Reward Last Episodes: 17.00
# Total Steps: 1136640, Episodes: 811, Mean Reward total: 1.50, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1141760, Episodes: 813, Mean Reward total: 4.30, Episodes since last print: 2, Mean Reward Last Episodes: 12.00
# Total Steps: 1146880, Episodes: 816, Mean Reward total: 6.90, Episodes since last print: 3, Mean Reward Last Episodes: 1.33
# Total Steps: 1152000, Episodes: 817, Mean Reward total: 4.20, Episodes since last print: 1, Mean Reward Last Episodes: -9.00
# Total Steps: 1157120, Episodes: 818, Mean Reward total: 4.20, Episodes since last print: 1, Mean Reward Last Episodes: -9.00
# Total Steps: 1162240, Episodes: 820, Mean Reward total: 6.30, Episodes since last print: 2, Mean Reward Last Episodes: 18.00
# Total Steps: 1167360, Episodes: 824, Mean Reward total: 9.30, Episodes since last print: 4, Mean Reward Last Episodes: 16.25
# Total Steps: 1172480, Episodes: 825, Mean Reward total: 9.70, Episodes since last print: 1, Mean Reward Last Episodes: -2.00
# Total Steps: 1177600, Episodes: 826, Mean Reward total: 9.90, Episodes since last print: 1, Mean Reward Last Episodes: 18.00
# Total Steps: 1182720, Episodes: 827, Mean Reward total: 12.60, Episodes since last print: 1, Mean Reward Last Episodes: 18.00
# Total Steps: 1187840, Episodes: 830, Mean Reward total: 11.20, Episodes since last print: 3, Mean Reward Last Episodes: 4.33
# Total Steps: 1192960, Episodes: 831, Mean Reward total: 10.70, Episodes since last print: 1, Mean Reward Last Episodes: 12.00
# Total Steps: 1198080, Episodes: 832, Mean Reward total: 8.40, Episodes since last print: 1, Mean Reward Last Episodes: -9.00
# Total Steps: 1203200, Episodes: 835, Mean Reward total: 8.60, Episodes since last print: 3, Mean Reward Last Episodes: 11.33
# Total Steps: 1208320, Episodes: 835, Mean Reward total: 8.60, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1213440, Episodes: 837, Mean Reward total: 6.50, Episodes since last print: 2, Mean Reward Last Episodes: 7.50
# Total Steps: 1218560, Episodes: 840, Mean Reward total: 6.70, Episodes since last print: 3, Mean Reward Last Episodes: 5.00
# Total Steps: 1223680, Episodes: 843, Mean Reward total: 6.10, Episodes since last print: 3, Mean Reward Last Episodes: 5.33
# Total Steps: 1228800, Episodes: 843, Mean Reward total: 6.10, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1233920, Episodes: 845, Mean Reward total: 7.50, Episodes since last print: 2, Mean Reward Last Episodes: 14.50
# Total Steps: 1239040, Episodes: 846, Mean Reward total: 4.30, Episodes since last print: 1, Mean Reward Last Episodes: -13.00
# Total Steps: 1244160, Episodes: 848, Mean Reward total: 5.30, Episodes since last print: 2, Mean Reward Last Episodes: 2.00
# Total Steps: 1249280, Episodes: 849, Mean Reward total: 5.00, Episodes since last print: 1, Mean Reward Last Episodes: -5.00
# Total Steps: 1254400, Episodes: 852, Mean Reward total: 2.50, Episodes since last print: 3, Mean Reward Last Episodes: 0.00
# Total Steps: 1259520, Episodes: 852, Mean Reward total: 2.50, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1264640, Episodes: 853, Mean Reward total: 1.00, Episodes since last print: 1, Mean Reward Last Episodes: -5.00
# Total Steps: 1269760, Episodes: 855, Mean Reward total: -0.40, Episodes since last print: 2, Mean Reward Last Episodes: 7.50
# Total Steps: 1274880, Episodes: 856, Mean Reward total: 0.40, Episodes since last print: 1, Mean Reward Last Episodes: -5.00
# Total Steps: 1280000, Episodes: 858, Mean Reward total: 0.80, Episodes since last print: 2, Mean Reward Last Episodes: 4.00
# Total Steps: 1285120, Episodes: 860, Mean Reward total: 3.20, Episodes since last print: 2, Mean Reward Last Episodes: 7.50
# Total Steps: 1290240, Episodes: 863, Mean Reward total: 5.80, Episodes since last print: 3, Mean Reward Last Episodes: 8.33
# Total Steps: 1295360, Episodes: 864, Mean Reward total: 4.90, Episodes since last print: 1, Mean Reward Last Episodes: 8.00
# Total Steps: 1300480, Episodes: 864, Mean Reward total: 4.90, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1305600, Episodes: 865, Mean Reward total: 6.20, Episodes since last print: 1, Mean Reward Last Episodes: 11.00
# Total Steps: 1310720, Episodes: 867, Mean Reward total: 4.50, Episodes since last print: 2, Mean Reward Last Episodes: -6.50
# Total Steps: 1315840, Episodes: 868, Mean Reward total: 6.30, Episodes since last print: 1, Mean Reward Last Episodes: 17.00
# Total Steps: 1320960, Episodes: 869, Mean Reward total: 3.60, Episodes since last print: 1, Mean Reward Last Episodes: -7.00
# Total Steps: 1326080, Episodes: 870, Mean Reward total: 4.20, Episodes since last print: 1, Mean Reward Last Episodes: 1.00
# Total Steps: 1331200, Episodes: 873, Mean Reward total: 3.20, Episodes since last print: 3, Mean Reward Last Episodes: 5.00
# Total Steps: 1336320, Episodes: 873, Mean Reward total: 3.20, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1341440, Episodes: 874, Mean Reward total: 2.00, Episodes since last print: 1, Mean Reward Last Episodes: -4.00
# Total Steps: 1346560, Episodes: 876, Mean Reward total: 3.70, Episodes since last print: 2, Mean Reward Last Episodes: 11.00
# Total Steps: 1351680, Episodes: 880, Mean Reward total: 7.40, Episodes since last print: 4, Mean Reward Last Episodes: 10.25
# Total Steps: 1356800, Episodes: 880, Mean Reward total: 7.40, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1361920, Episodes: 881, Mean Reward total: 9.50, Episodes since last print: 1, Mean Reward Last Episodes: 19.00
# Total Steps: 1367040, Episodes: 883, Mean Reward total: 10.10, Episodes since last print: 2, Mean Reward Last Episodes: 11.50
# Total Steps: 1372160, Episodes: 884, Mean Reward total: 11.70, Episodes since last print: 1, Mean Reward Last Episodes: 12.00
# Total Steps: 1377280, Episodes: 884, Mean Reward total: 11.70, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1382400, Episodes: 884, Mean Reward total: 11.70, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1387520, Episodes: 887, Mean Reward total: 8.90, Episodes since last print: 3, Mean Reward Last Episodes: 2.00
# Total Steps: 1392640, Episodes: 890, Mean Reward total: 7.70, Episodes since last print: 3, Mean Reward Last Episodes: 5.67
# Total Steps: 1397760, Episodes: 891, Mean Reward total: 6.50, Episodes since last print: 1, Mean Reward Last Episodes: 7.00
# Total Steps: 1402880, Episodes: 892, Mean Reward total: 5.90, Episodes since last print: 1, Mean Reward Last Episodes: 1.00
# Total Steps: 1408000, Episodes: 892, Mean Reward total: 5.90, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1413120, Episodes: 893, Mean Reward total: 6.20, Episodes since last print: 1, Mean Reward Last Episodes: 19.00
# Total Steps: 1418240, Episodes: 896, Mean Reward total: 6.70, Episodes since last print: 3, Mean Reward Last Episodes: 8.67
# Total Steps: 1423360, Episodes: 898, Mean Reward total: 7.00, Episodes since last print: 2, Mean Reward Last Episodes: -1.00
# Total Steps: 1428480, Episodes: 899, Mean Reward total: 6.00, Episodes since last print: 1, Mean Reward Last Episodes: 3.00
# Total Steps: 1433600, Episodes: 900, Mean Reward total: 7.20, Episodes since last print: 1, Mean Reward Last Episodes: 18.00
# Total Steps: 1438720, Episodes: 901, Mean Reward total: 7.60, Episodes since last print: 1, Mean Reward Last Episodes: 11.00
# Total Steps: 1443840, Episodes: 903, Mean Reward total: 7.20, Episodes since last print: 2, Mean Reward Last Episodes: 8.00
# Total Steps: 1448960, Episodes: 904, Mean Reward total: 5.40, Episodes since last print: 1, Mean Reward Last Episodes: -6.00
# Total Steps: 1454080, Episodes: 905, Mean Reward total: 4.60, Episodes since last print: 1, Mean Reward Last Episodes: -2.00
# Total Steps: 1459200, Episodes: 906, Mean Reward total: 3.10, Episodes since last print: 1, Mean Reward Last Episodes: -7.00
# Total Steps: 1464320, Episodes: 907, Mean Reward total: 3.20, Episodes since last print: 1, Mean Reward Last Episodes: -5.00
# Total Steps: 1469440, Episodes: 910, Mean Reward total: 2.50, Episodes since last print: 3, Mean Reward Last Episodes: 6.00
# Total Steps: 1474560, Episodes: 912, Mean Reward total: 1.70, Episodes since last print: 2, Mean Reward Last Episodes: 1.00
# Total Steps: 1479680, Episodes: 913, Mean Reward total: 0.30, Episodes since last print: 1, Mean Reward Last Episodes: 3.00
# Total Steps: 1484800, Episodes: 913, Mean Reward total: 0.30, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1489920, Episodes: 915, Mean Reward total: 3.90, Episodes since last print: 2, Mean Reward Last Episodes: 14.00
# Total Steps: 1495040, Episodes: 918, Mean Reward total: 4.50, Episodes since last print: 3, Mean Reward Last Episodes: 2.00
# Total Steps: 1500160, Episodes: 919, Mean Reward total: 5.30, Episodes since last print: 1, Mean Reward Last Episodes: 13.00
# Total Steps: 1505280, Episodes: 920, Mean Reward total: 4.80, Episodes since last print: 1, Mean Reward Last Episodes: -4.00
# Total Steps: 1510400, Episodes: 921, Mean Reward total: 5.50, Episodes since last print: 1, Mean Reward Last Episodes: 17.00
# Total Steps: 1515520, Episodes: 923, Mean Reward total: 7.60, Episodes since last print: 2, Mean Reward Last Episodes: 8.00
# Total Steps: 1520640, Episodes: 924, Mean Reward total: 6.80, Episodes since last print: 1, Mean Reward Last Episodes: 8.00
# Total Steps: 1525760, Episodes: 927, Mean Reward total: 5.10, Episodes since last print: 3, Mean Reward Last Episodes: 1.67
# Total Steps: 1530880, Episodes: 927, Mean Reward total: 5.10, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1536000, Episodes: 929, Mean Reward total: 8.10, Episodes since last print: 2, Mean Reward Last Episodes: 19.50
# Total Steps: 1541120, Episodes: 930, Mean Reward total: 8.60, Episodes since last print: 1, Mean Reward Last Episodes: 1.00
# Total Steps: 1546240, Episodes: 932, Mean Reward total: 6.50, Episodes since last print: 2, Mean Reward Last Episodes: 6.50
# Total Steps: 1551360, Episodes: 933, Mean Reward total: 7.10, Episodes since last print: 1, Mean Reward Last Episodes: 5.00
# Total Steps: 1556480, Episodes: 935, Mean Reward total: 8.50, Episodes since last print: 2, Mean Reward Last Episodes: 9.50
# Total Steps: 1561600, Episodes: 938, Mean Reward total: 8.20, Episodes since last print: 3, Mean Reward Last Episodes: 8.33
# Total Steps: 1566720, Episodes: 939, Mean Reward total: 6.40, Episodes since last print: 1, Mean Reward Last Episodes: 1.00
# Total Steps: 1571840, Episodes: 940, Mean Reward total: 8.10, Episodes since last print: 1, Mean Reward Last Episodes: 18.00
# Total Steps: 1576960, Episodes: 940, Mean Reward total: 8.10, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1582080, Episodes: 943, Mean Reward total: 7.10, Episodes since last print: 3, Mean Reward Last Episodes: 2.67
# Total Steps: 1587200, Episodes: 946, Mean Reward total: 4.20, Episodes since last print: 3, Mean Reward Last Episodes: 3.33
# Total Steps: 1592320, Episodes: 947, Mean Reward total: 4.20, Episodes since last print: 1, Mean Reward Last Episodes: 1.00
# Total Steps: 1597440, Episodes: 947, Mean Reward total: 4.20, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1602560, Episodes: 949, Mean Reward total: 6.00, Episodes since last print: 2, Mean Reward Last Episodes: 11.50
# Total Steps: 1607680, Episodes: 954, Mean Reward total: 8.60, Episodes since last print: 5, Mean Reward Last Episodes: 9.20
# Total Steps: 1612800, Episodes: 955, Mean Reward total: 8.50, Episodes since last print: 1, Mean Reward Last Episodes: 14.00
# Total Steps: 1617920, Episodes: 956, Mean Reward total: 10.00, Episodes since last print: 1, Mean Reward Last Episodes: 16.00
# Total Steps: 1623040, Episodes: 959, Mean Reward total: 12.80, Episodes since last print: 3, Mean Reward Last Episodes: 17.33
# Total Steps: 1628160, Episodes: 961, Mean Reward total: 14.70, Episodes since last print: 2, Mean Reward Last Episodes: 17.00
# Total Steps: 1633280, Episodes: 964, Mean Reward total: 15.10, Episodes since last print: 3, Mean Reward Last Episodes: 11.67
# Total Steps: 1638400, Episodes: 966, Mean Reward total: 15.60, Episodes since last print: 2, Mean Reward Last Episodes: 17.50
# Total Steps: 1643520, Episodes: 968, Mean Reward total: 14.50, Episodes since last print: 2, Mean Reward Last Episodes: 11.00
# Total Steps: 1648640, Episodes: 971, Mean Reward total: 13.70, Episodes since last print: 3, Mean Reward Last Episodes: 15.00
# Total Steps: 1653760, Episodes: 972, Mean Reward total: 14.20, Episodes since last print: 1, Mean Reward Last Episodes: 13.00
# Total Steps: 1658880, Episodes: 974, Mean Reward total: 13.90, Episodes since last print: 2, Mean Reward Last Episodes: 12.00
# Total Steps: 1664000, Episodes: 977, Mean Reward total: 14.70, Episodes since last print: 3, Mean Reward Last Episodes: 15.33
# Total Steps: 1669120, Episodes: 979, Mean Reward total: 13.00, Episodes since last print: 2, Mean Reward Last Episodes: 7.50
# Total Steps: 1674240, Episodes: 980, Mean Reward total: 12.60, Episodes since last print: 1, Mean Reward Last Episodes: 15.00
# Total Steps: 1679360, Episodes: 983, Mean Reward total: 11.90, Episodes since last print: 3, Mean Reward Last Episodes: 10.33
# Total Steps: 1684480, Episodes: 985, Mean Reward total: 11.00, Episodes since last print: 2, Mean Reward Last Episodes: 8.00
# Total Steps: 1689600, Episodes: 988, Mean Reward total: 11.00, Episodes since last print: 3, Mean Reward Last Episodes: 15.00
# Total Steps: 1694720, Episodes: 990, Mean Reward total: 12.30, Episodes since last print: 2, Mean Reward Last Episodes: 15.50
# Total Steps: 1699840, Episodes: 991, Mean Reward total: 11.50, Episodes since last print: 1, Mean Reward Last Episodes: 12.00
# Total Steps: 1704960, Episodes: 993, Mean Reward total: 11.70, Episodes since last print: 2, Mean Reward Last Episodes: 6.50
# Total Steps: 1710080, Episodes: 995, Mean Reward total: 12.50, Episodes since last print: 2, Mean Reward Last Episodes: 12.00
# Total Steps: 1715200, Episodes: 999, Mean Reward total: 7.40, Episodes since last print: 4, Mean Reward Last Episodes: 3.00
# Total Steps: 1720320, Episodes: 999, Mean Reward total: 7.40, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1725440, Episodes: 1001, Mean Reward total: 7.10, Episodes since last print: 2, Mean Reward Last Episodes: 11.00
# Total Steps: 1730560, Episodes: 1003, Mean Reward total: 7.10, Episodes since last print: 2, Mean Reward Last Episodes: 6.50
# Total Steps: 1735680, Episodes: 1006, Mean Reward total: 6.80, Episodes since last print: 3, Mean Reward Last Episodes: 8.33
# Total Steps: 1740800, Episodes: 1007, Mean Reward total: 5.50, Episodes since last print: 1, Mean Reward Last Episodes: 4.00
# Total Steps: 1745920, Episodes: 1009, Mean Reward total: 7.00, Episodes since last print: 2, Mean Reward Last Episodes: 3.00
# Total Steps: 1751040, Episodes: 1012, Mean Reward total: 8.00, Episodes since last print: 3, Mean Reward Last Episodes: 12.67
# Total Steps: 1756160, Episodes: 1013, Mean Reward total: 8.50, Episodes since last print: 1, Mean Reward Last Episodes: 12.00
# Total Steps: 1761280, Episodes: 1015, Mean Reward total: 8.20, Episodes since last print: 2, Mean Reward Last Episodes: 8.50
# Total Steps: 1766400, Episodes: 1017, Mean Reward total: 10.20, Episodes since last print: 2, Mean Reward Last Episodes: 14.50
# Total Steps: 1771520, Episodes: 1020, Mean Reward total: 11.50, Episodes since last print: 3, Mean Reward Last Episodes: 10.33
# Total Steps: 1776640, Episodes: 1022, Mean Reward total: 11.60, Episodes since last print: 2, Mean Reward Last Episodes: 13.50
# Total Steps: 1781760, Episodes: 1024, Mean Reward total: 11.50, Episodes since last print: 2, Mean Reward Last Episodes: 7.50
# Total Steps: 1786880, Episodes: 1027, Mean Reward total: 12.40, Episodes since last print: 3, Mean Reward Last Episodes: 17.00
# Total Steps: 1792000, Episodes: 1029, Mean Reward total: 12.30, Episodes since last print: 2, Mean Reward Last Episodes: 13.00
# Total Steps: 1797120, Episodes: 1031, Mean Reward total: 11.80, Episodes since last print: 2, Mean Reward Last Episodes: 10.00
# Total Steps: 1802240, Episodes: 1034, Mean Reward total: 13.60, Episodes since last print: 3, Mean Reward Last Episodes: 13.00
# Total Steps: 1807360, Episodes: 1036, Mean Reward total: 13.50, Episodes since last print: 2, Mean Reward Last Episodes: 17.00
# Total Steps: 1812480, Episodes: 1040, Mean Reward total: 14.90, Episodes since last print: 4, Mean Reward Last Episodes: 16.50
# Total Steps: 1817600, Episodes: 1040, Mean Reward total: 14.90, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 1822720, Episodes: 1042, Mean Reward total: 15.70, Episodes since last print: 2, Mean Reward Last Episodes: 16.00
# Total Steps: 1827840, Episodes: 1045, Mean Reward total: 14.90, Episodes since last print: 3, Mean Reward Last Episodes: 11.67
# Total Steps: 1832960, Episodes: 1047, Mean Reward total: 14.70, Episodes since last print: 2, Mean Reward Last Episodes: 15.50
# Total Steps: 1838080, Episodes: 1048, Mean Reward total: 13.70, Episodes since last print: 1, Mean Reward Last Episodes: 10.00
# Total Steps: 1843200, Episodes: 1051, Mean Reward total: 14.60, Episodes since last print: 3, Mean Reward Last Episodes: 17.67
# Total Steps: 1848320, Episodes: 1052, Mean Reward total: 14.40, Episodes since last print: 1, Mean Reward Last Episodes: 15.00
# Total Steps: 1853440, Episodes: 1056, Mean Reward total: 14.10, Episodes since last print: 4, Mean Reward Last Episodes: 11.75
# Total Steps: 1858560, Episodes: 1058, Mean Reward total: 15.20, Episodes since last print: 2, Mean Reward Last Episodes: 18.50
# Total Steps: 1863680, Episodes: 1060, Mean Reward total: 13.40, Episodes since last print: 2, Mean Reward Last Episodes: 8.50
# Total Steps: 1868800, Episodes: 1063, Mean Reward total: 14.10, Episodes since last print: 3, Mean Reward Last Episodes: 19.00
# Total Steps: 1873920, Episodes: 1066, Mean Reward total: 15.60, Episodes since last print: 3, Mean Reward Last Episodes: 15.00
# Total Steps: 1879040, Episodes: 1068, Mean Reward total: 15.60, Episodes since last print: 2, Mean Reward Last Episodes: 18.50
# Total Steps: 1884160, Episodes: 1069, Mean Reward total: 15.70, Episodes since last print: 1, Mean Reward Last Episodes: 20.00
# Total Steps: 1889280, Episodes: 1072, Mean Reward total: 16.50, Episodes since last print: 3, Mean Reward Last Episodes: 15.33
# Total Steps: 1894400, Episodes: 1075, Mean Reward total: 16.90, Episodes since last print: 3, Mean Reward Last Episodes: 17.00
# Total Steps: 1899520, Episodes: 1076, Mean Reward total: 17.20, Episodes since last print: 1, Mean Reward Last Episodes: 18.00
# Total Steps: 1904640, Episodes: 1080, Mean Reward total: 17.70, Episodes since last print: 4, Mean Reward Last Episodes: 19.00
# Total Steps: 1909760, Episodes: 1082, Mean Reward total: 17.20, Episodes since last print: 2, Mean Reward Last Episodes: 13.50
# Total Steps: 1914880, Episodes: 1084, Mean Reward total: 15.90, Episodes since last print: 2, Mean Reward Last Episodes: 10.50
# Total Steps: 1920000, Episodes: 1087, Mean Reward total: 16.20, Episodes since last print: 3, Mean Reward Last Episodes: 18.33
# Total Steps: 1925120, Episodes: 1090, Mean Reward total: 15.30, Episodes since last print: 3, Mean Reward Last Episodes: 16.67
# Total Steps: 1930240, Episodes: 1092, Mean Reward total: 16.10, Episodes since last print: 2, Mean Reward Last Episodes: 17.50
# Total Steps: 1935360, Episodes: 1094, Mean Reward total: 17.30, Episodes since last print: 2, Mean Reward Last Episodes: 16.50
# Total Steps: 1940480, Episodes: 1096, Mean Reward total: 17.00, Episodes since last print: 2, Mean Reward Last Episodes: 16.50
# Total Steps: 1945600, Episodes: 1099, Mean Reward total: 16.70, Episodes since last print: 3, Mean Reward Last Episodes: 15.33
# Total Steps: 1950720, Episodes: 1100, Mean Reward total: 16.00, Episodes since last print: 1, Mean Reward Last Episodes: 13.00
# ...
# Total Steps: 7879680, Episodes: 3778, Mean Reward total: 19.60, Episodes since last print: 1, Mean Reward Last Episodes: 21.00
# Total Steps: 7884800, Episodes: 3781, Mean Reward total: 19.80, Episodes since last print: 3, Mean Reward Last Episodes: 18.67
# Total Steps: 7889920, Episodes: 3784, Mean Reward total: 19.70, Episodes since last print: 3, Mean Reward Last Episodes: 20.00
# Total Steps: 7895040, Episodes: 3787, Mean Reward total: 19.70, Episodes since last print: 3, Mean Reward Last Episodes: 20.00
# Total Steps: 7900160, Episodes: 3789, Mean Reward total: 19.40, Episodes since last print: 2, Mean Reward Last Episodes: 19.50
# Total Steps: 7905280, Episodes: 3791, Mean Reward total: 20.00, Episodes since last print: 2, Mean Reward Last Episodes: 20.50
# Total Steps: 7910400, Episodes: 3793, Mean Reward total: 20.00, Episodes since last print: 2, Mean Reward Last Episodes: 20.00
# Total Steps: 7915520, Episodes: 3795, Mean Reward total: 20.10, Episodes since last print: 2, Mean Reward Last Episodes: 20.00
# Total Steps: 7920640, Episodes: 3798, Mean Reward total: 20.20, Episodes since last print: 3, Mean Reward Last Episodes: 20.67
# Total Steps: 7925760, Episodes: 3801, Mean Reward total: 20.20, Episodes since last print: 3, Mean Reward Last Episodes: 20.00
# Total Steps: 7930880, Episodes: 3803, Mean Reward total: 20.40, Episodes since last print: 2, Mean Reward Last Episodes: 21.00
# Total Steps: 7936000, Episodes: 3807, Mean Reward total: 20.30, Episodes since last print: 4, Mean Reward Last Episodes: 20.00
# Total Steps: 7941120, Episodes: 3809, Mean Reward total: 20.20, Episodes since last print: 2, Mean Reward Last Episodes: 20.50
# Total Steps: 7946240, Episodes: 3811, Mean Reward total: 20.20, Episodes since last print: 2, Mean Reward Last Episodes: 19.50
# Total Steps: 7951360, Episodes: 3812, Mean Reward total: 20.10, Episodes since last print: 1, Mean Reward Last Episodes: 20.00
# Total Steps: 7956480, Episodes: 3815, Mean Reward total: 20.10, Episodes since last print: 3, Mean Reward Last Episodes: 20.00
# Total Steps: 7961600, Episodes: 3818, Mean Reward total: 20.00, Episodes since last print: 3, Mean Reward Last Episodes: 20.33
# Total Steps: 7966720, Episodes: 3819, Mean Reward total: 19.90, Episodes since last print: 1, Mean Reward Last Episodes: 19.00
# Total Steps: 7971840, Episodes: 3822, Mean Reward total: 20.30, Episodes since last print: 3, Mean Reward Last Episodes: 21.00
# Total Steps: 7976960, Episodes: 3823, Mean Reward total: 19.90, Episodes since last print: 1, Mean Reward Last Episodes: 15.00
# Total Steps: 7982080, Episodes: 3826, Mean Reward total: 19.80, Episodes since last print: 3, Mean Reward Last Episodes: 20.33
# Total Steps: 7987200, Episodes: 3829, Mean Reward total: 19.50, Episodes since last print: 3, Mean Reward Last Episodes: 18.67
# Total Steps: 7992320, Episodes: 3830, Mean Reward total: 19.20, Episodes since last print: 1, Mean Reward Last Episodes: 18.00
# Total Steps: 7997440, Episodes: 3832, Mean Reward total: 19.10, Episodes since last print: 2, Mean Reward Last Episodes: 20.50
# Total Steps: 8002560, Episodes: 3836, Mean Reward total: 19.60, Episodes since last print: 4, Mean Reward Last Episodes: 20.25
# Total Steps: 8007680, Episodes: 3838, Mean Reward total: 19.20, Episodes since last print: 2, Mean Reward Last Episodes: 17.00
# Total Steps: 8012800, Episodes: 3840, Mean Reward total: 19.80, Episodes since last print: 2, Mean Reward Last Episodes: 21.00
# Total Steps: 8017920, Episodes: 3842, Mean Reward total: 19.90, Episodes since last print: 2, Mean Reward Last Episodes: 21.00
# Total Steps: 8023040, Episodes: 3844, Mean Reward total: 19.40, Episodes since last print: 2, Mean Reward Last Episodes: 18.50
# Total Steps: 8028160, Episodes: 3848, Mean Reward total: 19.50, Episodes since last print: 4, Mean Reward Last Episodes: 18.50
# Total Steps: 8033280, Episodes: 3848, Mean Reward total: 19.50, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 8038400, Episodes: 3851, Mean Reward total: 18.90, Episodes since last print: 3, Mean Reward Last Episodes: 19.00
# Total Steps: 8043520, Episodes: 3854, Mean Reward total: 18.90, Episodes since last print: 3, Mean Reward Last Episodes: 19.33
# Total Steps: 8048640, Episodes: 3857, Mean Reward total: 19.50, Episodes since last print: 3, Mean Reward Last Episodes: 20.33
# Total Steps: 8053760, Episodes: 3859, Mean Reward total: 19.90, Episodes since last print: 2, Mean Reward Last Episodes: 20.50
# Total Steps: 8058880, Episodes: 3862, Mean Reward total: 19.60, Episodes since last print: 3, Mean Reward Last Episodes: 19.00
# Total Steps: 8064000, Episodes: 3864, Mean Reward total: 20.10, Episodes since last print: 2, Mean Reward Last Episodes: 21.00
# Total Steps: 8069120, Episodes: 3866, Mean Reward total: 20.20, Episodes since last print: 2, Mean Reward Last Episodes: 20.50
# Total Steps: 8074240, Episodes: 3870, Mean Reward total: 20.00, Episodes since last print: 4, Mean Reward Last Episodes: 19.25
# Total Steps: 8079360, Episodes: 3872, Mean Reward total: 19.70, Episodes since last print: 2, Mean Reward Last Episodes: 18.50
# Total Steps: 8084480, Episodes: 3874, Mean Reward total: 19.70, Episodes since last print: 2, Mean Reward Last Episodes: 21.00
# Total Steps: 8089600, Episodes: 3878, Mean Reward total: 19.70, Episodes since last print: 4, Mean Reward Last Episodes: 20.25
# Total Steps: 8094720, Episodes: 3878, Mean Reward total: 19.70, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 8099840, Episodes: 3880, Mean Reward total: 19.50, Episodes since last print: 2, Mean Reward Last Episodes: 17.50
# Total Steps: 8104960, Episodes: 3884, Mean Reward total: 19.70, Episodes since last print: 4, Mean Reward Last Episodes: 20.25
# Total Steps: 8110080, Episodes: 3886, Mean Reward total: 19.60, Episodes since last print: 2, Mean Reward Last Episodes: 20.00
# Total Steps: 8115200, Episodes: 3889, Mean Reward total: 19.80, Episodes since last print: 3, Mean Reward Last Episodes: 20.00
# Total Steps: 8120320, Episodes: 3891, Mean Reward total: 20.00, Episodes since last print: 2, Mean Reward Last Episodes: 20.00
# Total Steps: 8125440, Episodes: 3893, Mean Reward total: 20.10, Episodes since last print: 2, Mean Reward Last Episodes: 21.00
# Total Steps: 8130560, Episodes: 3895, Mean Reward total: 20.10, Episodes since last print: 2, Mean Reward Last Episodes: 20.00
# Total Steps: 8135680, Episodes: 3898, Mean Reward total: 20.60, Episodes since last print: 3, Mean Reward Last Episodes: 21.00
# Total Steps: 8140800, Episodes: 3901, Mean Reward total: 20.00, Episodes since last print: 3, Mean Reward Last Episodes: 18.33
# Total Steps: 8145920, Episodes: 3904, Mean Reward total: 20.00, Episodes since last print: 3, Mean Reward Last Episodes: 20.33
# Total Steps: 8151040, Episodes: 3908, Mean Reward total: 19.60, Episodes since last print: 4, Mean Reward Last Episodes: 20.00
# Total Steps: 8156160, Episodes: 3908, Mean Reward total: 19.60, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 8161280, Episodes: 3912, Mean Reward total: 20.20, Episodes since last print: 4, Mean Reward Last Episodes: 20.25
# Total Steps: 8166400, Episodes: 3915, Mean Reward total: 20.00, Episodes since last print: 3, Mean Reward Last Episodes: 20.00
# Total Steps: 8171520, Episodes: 3916, Mean Reward total: 19.80, Episodes since last print: 1, Mean Reward Last Episodes: 18.00
# Total Steps: 8176640, Episodes: 3918, Mean Reward total: 19.90, Episodes since last print: 2, Mean Reward Last Episodes: 20.00
# Total Steps: 8181760, Episodes: 3921, Mean Reward total: 19.60, Episodes since last print: 3, Mean Reward Last Episodes: 19.33
# Total Steps: 8186880, Episodes: 3923, Mean Reward total: 19.00, Episodes since last print: 2, Mean Reward Last Episodes: 17.50
# Total Steps: 8192000, Episodes: 3926, Mean Reward total: 19.00, Episodes since last print: 3, Mean Reward Last Episodes: 19.00
# Total Steps: 8197120, Episodes: 3927, Mean Reward total: 19.10, Episodes since last print: 1, Mean Reward Last Episodes: 21.00
# Total Steps: 8202240, Episodes: 3930, Mean Reward total: 18.60, Episodes since last print: 3, Mean Reward Last Episodes: 18.67
# Total Steps: 8207360, Episodes: 3933, Mean Reward total: 19.30, Episodes since last print: 3, Mean Reward Last Episodes: 19.67
# Total Steps: 8212480, Episodes: 3934, Mean Reward total: 19.50, Episodes since last print: 1, Mean Reward Last Episodes: 19.00
# Total Steps: 8217600, Episodes: 3937, Mean Reward total: 19.60, Episodes since last print: 3, Mean Reward Last Episodes: 20.67
# Total Steps: 8222720, Episodes: 3941, Mean Reward total: 19.70, Episodes since last print: 4, Mean Reward Last Episodes: 19.50
# Total Steps: 8227840, Episodes: 3941, Mean Reward total: 19.70, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 8232960, Episodes: 3943, Mean Reward total: 19.60, Episodes since last print: 2, Mean Reward Last Episodes: 18.50
# Total Steps: 8238080, Episodes: 3946, Mean Reward total: 19.60, Episodes since last print: 3, Mean Reward Last Episodes: 20.00
# Total Steps: 8243200, Episodes: 3949, Mean Reward total: 19.30, Episodes since last print: 3, Mean Reward Last Episodes: 19.33
# Total Steps: 8248320, Episodes: 3950, Mean Reward total: 19.30, Episodes since last print: 1, Mean Reward Last Episodes: 20.00
# Total Steps: 8253440, Episodes: 3953, Mean Reward total: 19.80, Episodes since last print: 3, Mean Reward Last Episodes: 20.00
# Total Steps: 8258560, Episodes: 3956, Mean Reward total: 19.40, Episodes since last print: 3, Mean Reward Last Episodes: 18.67
# Total Steps: 8263680, Episodes: 3958, Mean Reward total: 19.10, Episodes since last print: 2, Mean Reward Last Episodes: 18.00
# Total Steps: 8268800, Episodes: 3960, Mean Reward total: 19.40, Episodes since last print: 2, Mean Reward Last Episodes: 21.00
# Total Steps: 8273920, Episodes: 3963, Mean Reward total: 19.20, Episodes since last print: 3, Mean Reward Last Episodes: 19.33
# Total Steps: 8279040, Episodes: 3967, Mean Reward total: 19.30, Episodes since last print: 4, Mean Reward Last Episodes: 19.50
# Total Steps: 8284160, Episodes: 3968, Mean Reward total: 19.90, Episodes since last print: 1, Mean Reward Last Episodes: 21.00
# Total Steps: 8289280, Episodes: 3971, Mean Reward total: 19.70, Episodes since last print: 3, Mean Reward Last Episodes: 20.00
# Total Steps: 8294400, Episodes: 3974, Mean Reward total: 19.90, Episodes since last print: 3, Mean Reward Last Episodes: 19.67
# Total Steps: 8299520, Episodes: 3975, Mean Reward total: 19.60, Episodes since last print: 1, Mean Reward Last Episodes: 18.00
# Total Steps: 8304640, Episodes: 3978, Mean Reward total: 19.70, Episodes since last print: 3, Mean Reward Last Episodes: 20.00
# Total Steps: 8309760, Episodes: 3982, Mean Reward total: 19.40, Episodes since last print: 4, Mean Reward Last Episodes: 19.50
# Total Steps: 8314880, Episodes: 3984, Mean Reward total: 19.60, Episodes since last print: 2, Mean Reward Last Episodes: 20.00
# Total Steps: 8320000, Episodes: 3985, Mean Reward total: 19.80, Episodes since last print: 1, Mean Reward Last Episodes: 20.00
# Total Steps: 8325120, Episodes: 3990, Mean Reward total: 19.80, Episodes since last print: 5, Mean Reward Last Episodes: 20.00
# Total Steps: 8330240, Episodes: 3991, Mean Reward total: 19.80, Episodes since last print: 1, Mean Reward Last Episodes: 19.00
# Total Steps: 8335360, Episodes: 3994, Mean Reward total: 20.20, Episodes since last print: 3, Mean Reward Last Episodes: 21.00
# Total Steps: 8340480, Episodes: 3997, Mean Reward total: 20.20, Episodes since last print: 3, Mean Reward Last Episodes: 19.00
# Total Steps: 8345600, Episodes: 3999, Mean Reward total: 19.50, Episodes since last print: 2, Mean Reward Last Episodes: 17.50
# Total Steps: 8350720, Episodes: 4001, Mean Reward total: 19.20, Episodes since last print: 2, Mean Reward Last Episodes: 18.50
# Total Steps: 8355840, Episodes: 4003, Mean Reward total: 18.70, Episodes since last print: 2, Mean Reward Last Episodes: 18.50
# Total Steps: 8360960, Episodes: 4006, Mean Reward total: 19.10, Episodes since last print: 3, Mean Reward Last Episodes: 21.00
# Total Steps: 8366080, Episodes: 4007, Mean Reward total: 19.10, Episodes since last print: 1, Mean Reward Last Episodes: 19.00
# Total Steps: 8371200, Episodes: 4011, Mean Reward total: 20.10, Episodes since last print: 4, Mean Reward Last Episodes: 20.50
# Total Steps: 8376320, Episodes: 4015, Mean Reward total: 20.00, Episodes since last print: 4, Mean Reward Last Episodes: 19.50
# Total Steps: 8381440, Episodes: 4016, Mean Reward total: 20.00, Episodes since last print: 1, Mean Reward Last Episodes: 21.00
# Total Steps: 8386560, Episodes: 4018, Mean Reward total: 20.00, Episodes since last print: 2, Mean Reward Last Episodes: 19.50
# Total Steps: 8391680, Episodes: 4021, Mean Reward total: 19.60, Episodes since last print: 3, Mean Reward Last Episodes: 19.33
# Total Steps: 8396800, Episodes: 4023, Mean Reward total: 20.00, Episodes since last print: 2, Mean Reward Last Episodes: 20.50
# Total Steps: 8401920, Episodes: 4026, Mean Reward total: 19.50, Episodes since last print: 3, Mean Reward Last Episodes: 19.00
# Total Steps: 8407040, Episodes: 4028, Mean Reward total: 19.30, Episodes since last print: 2, Mean Reward Last Episodes: 18.50
# Total Steps: 8412160, Episodes: 4029, Mean Reward total: 19.30, Episodes since last print: 1, Mean Reward Last Episodes: 21.00
# Total Steps: 8417280, Episodes: 4031, Mean Reward total: 19.60, Episodes since last print: 2, Mean Reward Last Episodes: 20.00
# Total Steps: 8422400, Episodes: 4034, Mean Reward total: 19.90, Episodes since last print: 3, Mean Reward Last Episodes: 20.67
# Total Steps: 8427520, Episodes: 4037, Mean Reward total: 20.00, Episodes since last print: 3, Mean Reward Last Episodes: 19.67
# Total Steps: 8432640, Episodes: 4039, Mean Reward total: 20.20, Episodes since last print: 2, Mean Reward Last Episodes: 20.50
# Total Steps: 8437760, Episodes: 4040, Mean Reward total: 20.30, Episodes since last print: 1, Mean Reward Last Episodes: 21.00
# Total Steps: 8442880, Episodes: 4041, Mean Reward total: 20.30, Episodes since last print: 1, Mean Reward Last Episodes: 20.00
# Total Steps: 8448000, Episodes: 4045, Mean Reward total: 19.60, Episodes since last print: 4, Mean Reward Last Episodes: 19.00
# Total Steps: 8453120, Episodes: 4047, Mean Reward total: 19.90, Episodes since last print: 2, Mean Reward Last Episodes: 20.50
# Total Steps: 8458240, Episodes: 4048, Mean Reward total: 19.90, Episodes since last print: 1, Mean Reward Last Episodes: 21.00
# Total Steps: 8463360, Episodes: 4051, Mean Reward total: 20.00, Episodes since last print: 3, Mean Reward Last Episodes: 20.67
# Total Steps: 8468480, Episodes: 4054, Mean Reward total: 20.10, Episodes since last print: 3, Mean Reward Last Episodes: 19.33
# Total Steps: 8473600, Episodes: 4056, Mean Reward total: 20.30, Episodes since last print: 2, Mean Reward Last Episodes: 20.50
# Total Steps: 8478720, Episodes: 4058, Mean Reward total: 20.30, Episodes since last print: 2, Mean Reward Last Episodes: 21.00
# Total Steps: 8483840, Episodes: 4060, Mean Reward total: 20.30, Episodes since last print: 2, Mean Reward Last Episodes: 21.00
# Total Steps: 8488960, Episodes: 4063, Mean Reward total: 19.90, Episodes since last print: 3, Mean Reward Last Episodes: 18.67
# Total Steps: 8494080, Episodes: 4066, Mean Reward total: 20.00, Episodes since last print: 3, Mean Reward Last Episodes: 20.00
# Total Steps: 8499200, Episodes: 4066, Mean Reward total: 20.00, Episodes since last print: 0, Mean Reward Last Episodes: 0.00
# Total Steps: 8504320, Episodes: 4070, Mean Reward total: 18.10, Episodes since last print: 4, Mean Reward Last Episodes: 16.25
# Total Steps: 8509440, Episodes: 4071, Mean Reward total: 18.70, Episodes since last print: 1, Mean Reward Last Episodes: 21.00
# Total Steps: 8514560, Episodes: 4074, Mean Reward total: 18.20, Episodes since last print: 3, Mean Reward Last Episodes: 18.67
# Time limit reached. Stopping training.
# Training complete!
# Total training time: 32401.68 seconds

# %% [markdown]
# ## Evaluation

# %%
def evaluate_model_ppo(model, config, num_episodes=10):
    env = gym.make(config.gym_id, render_mode='rgb_array', frameskip=1)
    env = AtariWrappers(env, config.frame_skip)
    env.reset(seed=config.seed)
    env.action_space.seed(config.seed)
    model.eval()
    device = torch.device(config.device)

    total_rewards = []
    for episode in range(num_episodes):
        state, _ = env.reset()
        state = torch.tensor(state, device=device)
        done = False
        episode_reward = 0
        while not done:
            with torch.no_grad():
                action, _, _, _ = model(state.unsqueeze(0))
                action = action.item()
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            episode_reward += reward
            state = torch.tensor(next_state, device=device)
        total_rewards.append(episode_reward)
    mean_reward = np.mean(total_rewards)
    std_reward = np.std(total_rewards)
    env.close()
    model.train()
    return mean_reward, std_reward

# %%
ppo_custom_mean_reward, ppo_custom_std_reward = evaluate_model_ppo(ppo_custom_model, config_ppo)
print(f"PPO Evaluation over 10 episodes: Mean Reward = {ppo_custom_mean_reward}, Std Reward = {ppo_custom_std_reward}")
# Out:
# /var/folders/nx/scf6msw549j5lvz4kv2gfpz00000gn/T/ipykernel_79379/85066328.py:12: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:281.)
#   state = torch.tensor(state, device=device)
# PPO Evaluation over 10 episodes: Mean Reward = 19.5, Std Reward = 1.6881943016134133

# %% [markdown]
# ##  Metrics

# %%
results_ppo = {
    'Episode Rewards': ppo_custom_episode_rewards,
    'Episode Times': ppo_episode_times,
    'Losses': ppo_custom_losses,
    'Loss Times': ppo_loss_times,
    'Threshold Times': ppo_threshold_times,
    'Total Training Time': ppo_custom_total_training_time,
    'Total Steps': ppo_custom_total_steps,
    'Total Episodes': ppo_custom_total_episodes,
    'Timesteps per Episode': ppo_custom_timesteps_per_episode,
    'Mean Evaluation Reward': ppo_custom_mean_reward,
    'Std Evaluation Reward': ppo_custom_std_reward
}

# Save results to JSON
ppo_metrics_path = f"./metrics/ppo_custom_metrics_{env_id}_{training_time_max}.json"
with open(ppo_metrics_path, 'w') as f:
    json.dump(results_ppo, f)

# Print Summary
print("=== Training Summary ===")
print(f"Total Training Time: {ppo_custom_total_training_time:.2f} seconds")
print(f"Total Steps: {ppo_custom_total_steps}")
print(f"Total Episodes: {ppo_custom_total_episodes}")
print(f"Average Timesteps per Episode: {ppo_custom_timesteps_per_episode:.2f}")
print(f"Final Mean Reward (last 10 episodes): {np.mean(ppo_custom_episode_rewards[-10:]):.2f}")
print(f"Evaluation Mean Reward: {ppo_custom_mean_reward:.2f}")
print(f"Evaluation Std Reward: {ppo_custom_std_reward:.2f}")
print(f"Threshold Times: {ppo_threshold_times}")
# Out:
# === Training Summary ===
# Total Training Time: 32401.68 seconds
# Total Steps: 8514560
# Total Episodes: 4074
# Average Timesteps per Episode: 2089.98
# Final Mean Reward (last 10 episodes): 18.20
# Evaluation Mean Reward: 19.50
# Evaluation Std Reward: 1.69
# Threshold Times: {0: 4006.7676961421967, 10: 4166.020635128021, 21: 6754.772814035416}

# %% [markdown]
# ## Save Model

# %%
# Save the Model
ppo_model_path = f"./models/ppo_custom_model_{env_id}_{training_time_max}.pth"
ppo_repo_path = f"ppo_custom_model_{env_id}_{training_time_max}.pth"
ppo_repo_path_metrics = f"ppo_custom_metrics_{env_id}_{training_time_max}.json"
torch.save(ppo_custom_model.state_dict(), ppo_model_path)

upload_file(
    path_or_fileobj=ppo_model_path,
    path_in_repo=ppo_repo_path,
    repo_id='maxstahl/ppo_pongnoframskip_v4_custom',
)

upload_file(
    path_or_fileobj=ppo_metrics_path,
    path_in_repo=ppo_repo_path_metrics,
    repo_id='maxstahl/ppo_pongnoframskip_v4_custom',
)
# Out:
# /Users/stahlma/anaconda3/envs/gymnasium/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:503: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# ppo_custom_model_PongNoFrameskip-v4_32400.pth:   0%|          | 0.00/6.76M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/maxstahl/ppo_pongnoframskip_v4_custom/commit/82858ef4d262f25f091a8f45abd8f62e009a6e06', commit_message='Upload ppo_custom_metrics_PongNoFrameskip-v4_32400.json with huggingface_hub', commit_description='', oid='82858ef4d262f25f091a8f45abd8f62e009a6e06', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# # A2C Implementation

# %% [markdown]
# ## Configuration

# %%
config_dict_a2c = {
    'device': 'cuda' if torch.cuda.is_available() else 'cpu',
    'gym_id': env_id,
    'total_timesteps': 1e17,
    'n_envs': 8,
    'n_steps': 128,  # Number of steps per rollout in A2C
    'frame_skip': 4,
    'hidden_size': 512,
    'learning_rate': 7e-4,
    'gamma': 0.99,
    'gae': True,
    'gae_lambda': 0.95,  # Not used when GAE is False
    'entropy_coef': 0.01,
    'value_loss_coef': 0.25,
    'max_grad_norm': 0.5,
    'normalize_advantage': True,
    'time_limit': training_time_max,  # 60 seconds for testing
    'seed': seed
}

# Convert to Config Class
config_a2c = Config(config_dict_a2c)

# %% [markdown]
# ## Environment

# %%
envs_a2c = gym.vector.AsyncVectorEnv([
    make_env(config_a2c.gym_id, seed + i, config_a2c.frame_skip, clip_rewards=True) for i in range(config_a2c.n_envs)
])
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
#
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
#
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]

# %% [markdown]
# ## Neural Network

# %%
class A2CNetwork(nn.Module):
    def __init__(self, input_shape, n_actions, hidden_size=512):
        super().__init__()
        self.base = nn.Sequential(
            layer_init(nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4)),
            nn.ReLU(),
            layer_init(nn.Conv2d(32, 64, kernel_size=4, stride=2)),
            nn.ReLU(),
            layer_init(nn.Conv2d(64, 64, kernel_size=3, stride=1)),
            nn.ReLU(),
            nn.Flatten(),
            layer_init(nn.Linear(64 * 7 * 7, hidden_size)),
            nn.ReLU()
        )
        self.actor = layer_init(nn.Linear(hidden_size, n_actions), std=0.01)
        self.critic = layer_init(nn.Linear(hidden_size, 1), std=1.0)

    def forward(self, x):
        x = x / 255.0  # Normalize pixel values
        x = self.base(x)
        logits = self.actor(x)
        value = self.critic(x).squeeze(-1)
        return logits, value

# %% [markdown]
# ## Training

# %%
def train_a2c(config):
    device = torch.device(config.device)
    n_actions = envs_a2c.single_action_space.n
    input_shape = envs_a2c.single_observation_space.shape

    model = A2CNetwork(input_shape, n_actions, config.hidden_size).to(device)
    optimizer = optim.RMSprop(model.parameters(), lr=config.learning_rate, alpha=0.99, eps=1e-5)

    # Initialize storage
    obs_shape = envs_a2c.single_observation_space.shape
    states = torch.zeros((config.n_steps, config.n_envs) + obs_shape).to(device)
    actions = torch.zeros((config.n_steps, config.n_envs)).to(device)
    rewards = torch.zeros((config.n_steps, config.n_envs)).to(device)
    dones = torch.zeros((config.n_steps, config.n_envs)).to(device)
    values = torch.zeros((config.n_steps, config.n_envs)).to(device)

    # Metrics
    episode_rewards = []
    losses = []
    total_steps = 0
    total_episodes = 0

    # Initialize time tracking
    start_time = time.time()
    episode_times = []  # Record the time when each episode ends
    loss_times = []     # Record the time when each loss is calculated
    threshold_times = {0: None, 10: None, 21: None}  # For convergence speed metric

    # Start training
    state, _ = envs_a2c.reset()
    state = torch.tensor(state).to(device)
    done = torch.zeros(config.n_envs).to(device)

    # Episode tracking
    episode_rewards_env = np.zeros(config.n_envs)
    episode_lengths_env = np.zeros(config.n_envs)

    while total_steps < config.total_timesteps:
        current_time = time.time()
        if current_time - start_time > config.time_limit:
            print("Time limit reached. Stopping training.")
            break

        # Collect rollout data
        for step in range(config.n_steps):
            with torch.no_grad():
                logits, value = model(state)
                probs = torch.distributions.Categorical(logits=logits)
                action = probs.sample()
            log_prob = probs.log_prob(action)
            entropy = probs.entropy()
            values[step] = value
            actions[step] = action
            states[step] = state
            dones[step] = done

            next_state, reward, terminated, truncated, infos = envs_a2c.step(action.cpu().numpy())
            done = np.logical_or(terminated, truncated)
            rewards[step] = torch.tensor(reward).to(device)
            state = torch.tensor(next_state).to(device)
            done = torch.tensor(done).to(device)

            # Update episode rewards and lengths
            episode_rewards_env += reward
            episode_lengths_env += 1
            for idx, d in enumerate(done):
                if d:
                    episode_rewards.append(episode_rewards_env[idx])

                    # Record episode time
                    elapsed_time = time.time() - start_time
                    episode_times.append(elapsed_time)

                    # Check convergence thresholds
                    cumulative_reward = episode_rewards_env[idx]
                    for threshold in threshold_times:
                        if cumulative_reward >= threshold and threshold_times[threshold] is None:
                            threshold_times[threshold] = elapsed_time

                    episode_rewards_env[idx] = 0
                    total_episodes += 1
                    episode_lengths_env[idx] = 0

            total_steps += config.n_envs

        # Compute advantages and returns using GAE
        with torch.no_grad():
            next_value = model(state)[1]
            advantages = torch.zeros_like(rewards).to(device)
            lastgaelam = 0
            for t in reversed(range(config.n_steps)):
                if t == config.n_steps - 1:
                    nextnonterminal = 1.0 - done.float()
                    next_values = next_value
                else:
                    nextnonterminal = 1.0 - dones[t + 1].float()
                    next_values = values[t + 1]
                delta = rewards[t] + config.gamma * next_values * nextnonterminal - values[t]
                advantages[t] = lastgaelam = delta + config.gamma * config.gae_lambda * nextnonterminal * lastgaelam
            returns = advantages + values

        # Flatten the batch
        b_states = states.reshape((-1,) + obs_shape)
        b_actions = actions.reshape(-1)
        b_returns = returns.reshape(-1)
        b_advantages = advantages.reshape(-1)

        # Normalize advantages
        if config.normalize_advantage:
            b_advantages = (b_advantages - b_advantages.mean()) / (b_advantages.std() + 1e-8)

        # Recompute logits and values
        logits, values_pred = model(b_states)
        values_pred = values_pred 
        probs = torch.distributions.Categorical(logits=logits)
        log_probs = probs.log_prob(b_actions.long())
        entropy = probs.entropy().mean()

        # Compute losses
        policy_loss = -(b_advantages * log_probs).mean()
        value_loss = nn.functional.mse_loss(values_pred, b_returns)
        entropy_loss = entropy

        loss = policy_loss + config.value_loss_coef * value_loss - config.entropy_coef * entropy_loss
        losses.append(loss.item())

        # Record time at loss calculation
        loss_times.append(time.time() - start_time)

        # Optimize
        optimizer.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), config.max_grad_norm)
        optimizer.step()

        # Print progress
        if total_steps % (config.n_envs * 1000) == 0:
            mean_reward = np.mean(episode_rewards[-10:]) if len(episode_rewards) >= 10 else np.mean(episode_rewards)
            print(f"Total Steps: {total_steps}, Episodes: {total_episodes}, Mean Reward: {mean_reward:.2f}")

    total_training_time = time.time() - start_time
    timesteps_per_episode = total_steps / total_episodes if total_episodes > 0 else 0
    print("Training complete!")
    print(f"Total training time: {total_training_time:.2f} seconds")
    envs_a2c.close()
    return model, episode_rewards, total_training_time, losses, total_steps, total_episodes, timesteps_per_episode, episode_times, loss_times, threshold_times

# %%
a2c_custom_model, a2c_custom_episode_rewards, a2c_custom_total_training_time, a2c_custom_losses, a2c_custom_total_steps, a2c_custom_total_episodes, a2c_custom_timesteps_per_episode, a2c_episode_times, a2c_loss_times, a2c_threshold_times = train_a2c(config_a2c)
# Out:
# Total Steps: 128000, Episodes: 136, Mean Reward: -19.90
# Total Steps: 256000, Episodes: 270, Mean Reward: -20.00
# Total Steps: 384000, Episodes: 408, Mean Reward: -20.90
# Total Steps: 512000, Episodes: 542, Mean Reward: -19.10
# Total Steps: 640000, Episodes: 681, Mean Reward: -20.30
# Total Steps: 768000, Episodes: 820, Mean Reward: -20.30
# Total Steps: 896000, Episodes: 959, Mean Reward: -20.20
# Total Steps: 1024000, Episodes: 1098, Mean Reward: -20.50
# Total Steps: 1152000, Episodes: 1237, Mean Reward: -20.40
# Total Steps: 1280000, Episodes: 1376, Mean Reward: -20.30
# Total Steps: 1408000, Episodes: 1514, Mean Reward: -20.70
# Total Steps: 1536000, Episodes: 1649, Mean Reward: -20.10
# Total Steps: 1664000, Episodes: 1784, Mean Reward: -19.90
# Total Steps: 1792000, Episodes: 1916, Mean Reward: -19.90
# Total Steps: 1920000, Episodes: 2044, Mean Reward: -19.90
# Total Steps: 2048000, Episodes: 2164, Mean Reward: -19.20
# Total Steps: 2176000, Episodes: 2268, Mean Reward: -18.70
# Total Steps: 2304000, Episodes: 2354, Mean Reward: -18.50
# Total Steps: 2432000, Episodes: 2426, Mean Reward: -19.10
# Total Steps: 2560000, Episodes: 2484, Mean Reward: -16.50
# Total Steps: 2688000, Episodes: 2540, Mean Reward: -17.30
# Total Steps: 2816000, Episodes: 2591, Mean Reward: -16.60
# Total Steps: 2944000, Episodes: 2645, Mean Reward: -15.30
# Total Steps: 3072000, Episodes: 2698, Mean Reward: -13.10
# Total Steps: 3200000, Episodes: 2757, Mean Reward: -17.30
# Total Steps: 3328000, Episodes: 2818, Mean Reward: -17.00
# Total Steps: 3456000, Episodes: 2873, Mean Reward: -14.40
# Total Steps: 3584000, Episodes: 2927, Mean Reward: -14.70
# Total Steps: 3712000, Episodes: 2980, Mean Reward: -12.00
# Total Steps: 3840000, Episodes: 3028, Mean Reward: -13.00
# Total Steps: 3968000, Episodes: 3077, Mean Reward: -13.60
# Total Steps: 4096000, Episodes: 3128, Mean Reward: -15.50
# Total Steps: 4224000, Episodes: 3175, Mean Reward: -13.30
# Total Steps: 4352000, Episodes: 3220, Mean Reward: -12.30
# Total Steps: 4480000, Episodes: 3266, Mean Reward: -13.30
# Total Steps: 4608000, Episodes: 3310, Mean Reward: -13.10
# Total Steps: 4736000, Episodes: 3353, Mean Reward: -11.30
# Total Steps: 4864000, Episodes: 3389, Mean Reward: -5.30
# Total Steps: 4992000, Episodes: 3425, Mean Reward: -9.10
# Total Steps: 5120000, Episodes: 3457, Mean Reward: -1.60
# Total Steps: 5248000, Episodes: 3496, Mean Reward: 1.40
# Total Steps: 5376000, Episodes: 3541, Mean Reward: 4.60
# Total Steps: 5504000, Episodes: 3581, Mean Reward: 1.60
# Total Steps: 5632000, Episodes: 3624, Mean Reward: 12.40
# Total Steps: 5760000, Episodes: 3660, Mean Reward: 11.20
# Total Steps: 5888000, Episodes: 3699, Mean Reward: 13.20
# Total Steps: 6016000, Episodes: 3744, Mean Reward: 9.20
# Total Steps: 6144000, Episodes: 3785, Mean Reward: 9.30
# Total Steps: 6272000, Episodes: 3831, Mean Reward: 13.50
# Total Steps: 6400000, Episodes: 3876, Mean Reward: 15.10
# Total Steps: 6528000, Episodes: 3923, Mean Reward: 14.10
# Total Steps: 6656000, Episodes: 3972, Mean Reward: 17.20
# Total Steps: 6784000, Episodes: 4024, Mean Reward: 17.90
# Total Steps: 6912000, Episodes: 4077, Mean Reward: 18.50
# Total Steps: 7040000, Episodes: 4128, Mean Reward: 18.30
# Total Steps: 7168000, Episodes: 4183, Mean Reward: 18.60
# Total Steps: 7296000, Episodes: 4238, Mean Reward: 18.90
# Total Steps: 7424000, Episodes: 4290, Mean Reward: 18.10
# Total Steps: 7552000, Episodes: 4344, Mean Reward: 18.30
# Total Steps: 7680000, Episodes: 4397, Mean Reward: 19.40
# Total Steps: 7808000, Episodes: 4451, Mean Reward: 19.70
# Total Steps: 7936000, Episodes: 4506, Mean Reward: 19.20
# Total Steps: 8064000, Episodes: 4557, Mean Reward: 19.70
# Total Steps: 8192000, Episodes: 4612, Mean Reward: 19.90
# Total Steps: 8320000, Episodes: 4668, Mean Reward: 20.00
# Total Steps: 8448000, Episodes: 4722, Mean Reward: 20.60
# Total Steps: 8576000, Episodes: 4779, Mean Reward: 19.70
# Total Steps: 8704000, Episodes: 4833, Mean Reward: 19.20
# Total Steps: 8832000, Episodes: 4886, Mean Reward: 19.80
# Total Steps: 8960000, Episodes: 4941, Mean Reward: 19.90
# Total Steps: 9088000, Episodes: 4996, Mean Reward: 20.20
# Total Steps: 9216000, Episodes: 5052, Mean Reward: 20.70
# Total Steps: 9344000, Episodes: 5109, Mean Reward: 20.20
# Total Steps: 9472000, Episodes: 5166, Mean Reward: 20.50
# Total Steps: 9600000, Episodes: 5223, Mean Reward: 20.70
# Total Steps: 9728000, Episodes: 5276, Mean Reward: 20.30
# Total Steps: 9856000, Episodes: 5333, Mean Reward: 20.60
# Total Steps: 9984000, Episodes: 5390, Mean Reward: 20.60
# Total Steps: 10112000, Episodes: 5444, Mean Reward: 20.20
# Total Steps: 10240000, Episodes: 5496, Mean Reward: 17.80
# Total Steps: 10368000, Episodes: 5555, Mean Reward: 20.80
# Total Steps: 10496000, Episodes: 5611, Mean Reward: 20.70
# Total Steps: 10624000, Episodes: 5667, Mean Reward: 20.60
# Total Steps: 10752000, Episodes: 5723, Mean Reward: 20.00
# Total Steps: 10880000, Episodes: 5780, Mean Reward: 20.00
# Total Steps: 11008000, Episodes: 5834, Mean Reward: 20.20
# Total Steps: 11136000, Episodes: 5892, Mean Reward: 21.00
# Total Steps: 11264000, Episodes: 5950, Mean Reward: 20.80
# Total Steps: 11392000, Episodes: 6006, Mean Reward: 20.40
# Total Steps: 11520000, Episodes: 6063, Mean Reward: 20.50
# Total Steps: 11648000, Episodes: 6116, Mean Reward: 20.60
# Total Steps: 11776000, Episodes: 6173, Mean Reward: 20.40
# Total Steps: 11904000, Episodes: 6225, Mean Reward: 19.20
# Total Steps: 12032000, Episodes: 6281, Mean Reward: 20.40
# Total Steps: 12160000, Episodes: 6336, Mean Reward: 20.90
# Total Steps: 12288000, Episodes: 6391, Mean Reward: 19.50
# Total Steps: 12416000, Episodes: 6448, Mean Reward: 19.10
# Total Steps: 12544000, Episodes: 6505, Mean Reward: 20.50
# Total Steps: 12672000, Episodes: 6564, Mean Reward: 20.60
# Total Steps: 12800000, Episodes: 6618, Mean Reward: 20.20
# Total Steps: 12928000, Episodes: 6674, Mean Reward: 20.70
# Total Steps: 13056000, Episodes: 6730, Mean Reward: 20.90
# Total Steps: 13184000, Episodes: 6787, Mean Reward: 20.90
# Total Steps: 13312000, Episodes: 6842, Mean Reward: 20.90
# Total Steps: 13440000, Episodes: 6902, Mean Reward: 21.00
# Total Steps: 13568000, Episodes: 6957, Mean Reward: 20.20
# Total Steps: 13696000, Episodes: 7014, Mean Reward: 21.00
# Total Steps: 13824000, Episodes: 7070, Mean Reward: 21.00
# Total Steps: 13952000, Episodes: 7129, Mean Reward: 20.50
# Total Steps: 14080000, Episodes: 7188, Mean Reward: 21.00
# Total Steps: 14208000, Episodes: 7241, Mean Reward: 17.50
# Total Steps: 14336000, Episodes: 7296, Mean Reward: 20.80
# Total Steps: 14464000, Episodes: 7353, Mean Reward: 18.60
# Total Steps: 14592000, Episodes: 7411, Mean Reward: 20.40
# Total Steps: 14720000, Episodes: 7467, Mean Reward: 20.80
# Total Steps: 14848000, Episodes: 7523, Mean Reward: 21.00
# Total Steps: 14976000, Episodes: 7582, Mean Reward: 20.50
# Total Steps: 15104000, Episodes: 7638, Mean Reward: 20.30
# Total Steps: 15232000, Episodes: 7691, Mean Reward: 20.40
# Total Steps: 15360000, Episodes: 7749, Mean Reward: 20.90
# Total Steps: 15488000, Episodes: 7806, Mean Reward: 20.50
# Total Steps: 15616000, Episodes: 7863, Mean Reward: 20.80
# Total Steps: 15744000, Episodes: 7919, Mean Reward: 20.60
# Total Steps: 15872000, Episodes: 7979, Mean Reward: 21.00
# Total Steps: 16000000, Episodes: 8036, Mean Reward: 20.90
# Total Steps: 16128000, Episodes: 8092, Mean Reward: 20.80
# Total Steps: 16256000, Episodes: 8149, Mean Reward: 20.80
# Total Steps: 16384000, Episodes: 8206, Mean Reward: 20.60
# Total Steps: 16512000, Episodes: 8262, Mean Reward: 20.80
# Total Steps: 16640000, Episodes: 8320, Mean Reward: 20.70
# Total Steps: 16768000, Episodes: 8377, Mean Reward: 20.70
# Total Steps: 16896000, Episodes: 8433, Mean Reward: 18.60
# Total Steps: 17024000, Episodes: 8490, Mean Reward: 20.70
# Total Steps: 17152000, Episodes: 8545, Mean Reward: 21.00
# Total Steps: 17280000, Episodes: 8603, Mean Reward: 21.00
# Total Steps: 17408000, Episodes: 8660, Mean Reward: 21.00
# Total Steps: 17536000, Episodes: 8718, Mean Reward: 21.00
# Total Steps: 17664000, Episodes: 8775, Mean Reward: 20.90
# Total Steps: 17792000, Episodes: 8832, Mean Reward: 20.80
# Total Steps: 17920000, Episodes: 8887, Mean Reward: 20.30
# Total Steps: 18048000, Episodes: 8943, Mean Reward: 20.40
# Total Steps: 18176000, Episodes: 8998, Mean Reward: 20.90
# Total Steps: 18304000, Episodes: 9056, Mean Reward: 20.80
# Total Steps: 18432000, Episodes: 9113, Mean Reward: 20.90
# Total Steps: 18560000, Episodes: 9170, Mean Reward: 21.00
# Total Steps: 18688000, Episodes: 9226, Mean Reward: 19.60
# Total Steps: 18816000, Episodes: 9284, Mean Reward: 21.00
# Total Steps: 18944000, Episodes: 9341, Mean Reward: 21.00
# Total Steps: 19072000, Episodes: 9399, Mean Reward: 21.00
# Total Steps: 19200000, Episodes: 9456, Mean Reward: 20.90
# Total Steps: 19328000, Episodes: 9512, Mean Reward: 20.70
# Total Steps: 19456000, Episodes: 9569, Mean Reward: 20.40
# Total Steps: 19584000, Episodes: 9624, Mean Reward: 20.70
# Total Steps: 19712000, Episodes: 9684, Mean Reward: 20.40
# Total Steps: 19840000, Episodes: 9737, Mean Reward: 20.60
# Total Steps: 19968000, Episodes: 9792, Mean Reward: 21.00
# Total Steps: 20096000, Episodes: 9851, Mean Reward: 21.00
# Total Steps: 20224000, Episodes: 9908, Mean Reward: 21.00
# Total Steps: 20352000, Episodes: 9965, Mean Reward: 20.00
# Total Steps: 20480000, Episodes: 10021, Mean Reward: 21.00
# Total Steps: 20608000, Episodes: 10078, Mean Reward: 20.60
# Total Steps: 20736000, Episodes: 10134, Mean Reward: 19.80
# Total Steps: 20864000, Episodes: 10192, Mean Reward: 20.90
# Total Steps: 20992000, Episodes: 10246, Mean Reward: 21.00
# Total Steps: 21120000, Episodes: 10304, Mean Reward: 20.90
# Total Steps: 21248000, Episodes: 10360, Mean Reward: 20.90
# Total Steps: 21376000, Episodes: 10416, Mean Reward: 20.80
# Total Steps: 21504000, Episodes: 10473, Mean Reward: 21.00
# Total Steps: 21632000, Episodes: 10530, Mean Reward: 20.90
# Total Steps: 21760000, Episodes: 10587, Mean Reward: 20.00
# Total Steps: 21888000, Episodes: 10645, Mean Reward: 20.40
# Total Steps: 22016000, Episodes: 10703, Mean Reward: 20.80
# Total Steps: 22144000, Episodes: 10758, Mean Reward: 20.10
# Total Steps: 22272000, Episodes: 10814, Mean Reward: 20.60
# Total Steps: 22400000, Episodes: 10871, Mean Reward: 20.90
# Total Steps: 22528000, Episodes: 10927, Mean Reward: 20.70
# Total Steps: 22656000, Episodes: 10986, Mean Reward: 20.50
# Total Steps: 22784000, Episodes: 11043, Mean Reward: 20.70
# Total Steps: 22912000, Episodes: 11098, Mean Reward: 20.40
# Total Steps: 23040000, Episodes: 11156, Mean Reward: 20.90
# Total Steps: 23168000, Episodes: 11214, Mean Reward: 20.80
# Total Steps: 23296000, Episodes: 11270, Mean Reward: 21.00
# Total Steps: 23424000, Episodes: 11328, Mean Reward: 20.70
# Total Steps: 23552000, Episodes: 11382, Mean Reward: 20.90
# Total Steps: 23680000, Episodes: 11440, Mean Reward: 20.90
# Total Steps: 23808000, Episodes: 11496, Mean Reward: 20.60
# Total Steps: 23936000, Episodes: 11555, Mean Reward: 20.30
# Total Steps: 24064000, Episodes: 11612, Mean Reward: 21.00
# Total Steps: 24192000, Episodes: 11668, Mean Reward: 20.80
# Total Steps: 24320000, Episodes: 11723, Mean Reward: 20.70
# Total Steps: 24448000, Episodes: 11780, Mean Reward: 20.90
# Total Steps: 24576000, Episodes: 11837, Mean Reward: 20.40
# Total Steps: 24704000, Episodes: 11891, Mean Reward: 21.00
# Total Steps: 24832000, Episodes: 11949, Mean Reward: 21.00
# Total Steps: 24960000, Episodes: 12008, Mean Reward: 20.90
# Total Steps: 25088000, Episodes: 12065, Mean Reward: 20.80
# Total Steps: 25216000, Episodes: 12123, Mean Reward: 20.10
# Total Steps: 25344000, Episodes: 12178, Mean Reward: 20.70
# Total Steps: 25472000, Episodes: 12237, Mean Reward: 21.00
# Total Steps: 25600000, Episodes: 12295, Mean Reward: 20.90
# Total Steps: 25728000, Episodes: 12351, Mean Reward: 20.90
# Total Steps: 25856000, Episodes: 12409, Mean Reward: 21.00
# Total Steps: 25984000, Episodes: 12466, Mean Reward: 21.00
# Total Steps: 26112000, Episodes: 12524, Mean Reward: 21.00
# Total Steps: 26240000, Episodes: 12582, Mean Reward: 20.90
# Total Steps: 26368000, Episodes: 12638, Mean Reward: 20.70
# Total Steps: 26496000, Episodes: 12693, Mean Reward: 20.70
# Total Steps: 26624000, Episodes: 12749, Mean Reward: 20.90
# Total Steps: 26752000, Episodes: 12806, Mean Reward: 20.60
# Total Steps: 26880000, Episodes: 12866, Mean Reward: 21.00
# Total Steps: 27008000, Episodes: 12922, Mean Reward: 19.90
# Time limit reached. Stopping training.
# Training complete!
# Total training time: 32400.47 seconds

# %% [markdown]
# ## Evaluation

# %%
def evaluate_model_a2c(model, config, num_episodes=10):
    env = gym.make(config.gym_id, render_mode='rgb_array', frameskip=1)
    env = AtariWrappers(env, config.frame_skip)
    env.reset(seed=config.seed)
    env.action_space.seed(config.seed)
    model.eval()
    device = torch.device(config.device)

    total_rewards = []
    for episode in range(num_episodes):
        state, _ = env.reset()
        state = torch.tensor(state, device=device)
        done = False
        episode_reward = 0
        while not done:
            with torch.no_grad():
                logits, _ = model(state.unsqueeze(0))
                probs = torch.distributions.Categorical(logits=logits)
                action = probs.sample().item()
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            episode_reward += reward
            state = torch.tensor(next_state, device=device)
        total_rewards.append(episode_reward)
    mean_reward = np.mean(total_rewards)
    std_reward = np.std(total_rewards)
    env.close()
    model.train()
    return mean_reward, std_reward

# %%
a2c_custom_mean_reward, a2c_custom_std_reward = evaluate_model_a2c(a2c_custom_model, config_a2c)
print(f"A2C Evaluation over 10 episodes: Mean Reward = {a2c_custom_mean_reward}, Std Reward = {a2c_custom_std_reward}")
# Out:
# A2C Evaluation over 10 episodes: Mean Reward = 20.7, Std Reward = 0.9

# %% [markdown]
# ## Metrics

# %%
results_a2c = {
  'Episode Rewards': a2c_custom_episode_rewards,
  'Episode Times': a2c_episode_times,
  'Losses': a2c_custom_losses,
  'Loss Times': a2c_loss_times,
  'Threshold Times': a2c_threshold_times,
  'Total Training Time': a2c_custom_total_training_time,
  'Total Steps': a2c_custom_total_steps,
  'Total Episodes': a2c_custom_total_episodes,
  'Timesteps per Episode': a2c_custom_timesteps_per_episode,
  'Mean Evaluation Reward': a2c_custom_mean_reward,
  'Std Evaluation Reward': a2c_custom_std_reward
}

a2c_metrics_path =f"./metrics/a2c_custom_metrics_{env_id}_{training_time_max}.json"
with open(a2c_metrics_path, 'w') as f:
  json.dump(results_a2c, f)

# Print Summary
print("=== Training Summary ===")
print(f"Total Training Time: {a2c_custom_total_training_time:.2f} seconds")
print(f"Total Steps: {a2c_custom_total_steps}")
print(f"Total Episodes: {a2c_custom_total_episodes}")
print(f"Average Timesteps per Episode: {a2c_custom_timesteps_per_episode:.2f}")
print(f"Final Mean Reward (last 10 episodes): {np.mean(a2c_custom_episode_rewards[-10:]):.2f}")
print(f"Evaluation Mean Reward: {a2c_custom_mean_reward:.2f}")
print(f"Evaluation Std Reward: {a2c_custom_std_reward:.2f}")
print(f"Threshold Times: {a2c_threshold_times}")
# Out:
# === Training Summary ===
# Total Training Time: 32400.47 seconds
# Total Steps: 27022336
# Total Episodes: 12929
# Average Timesteps per Episode: 2090.06
# Final Mean Reward (last 10 episodes): 21.00
# Evaluation Mean Reward: 20.70
# Evaluation Std Reward: 0.90
# Threshold Times: {0: 5608.170121192932, 10: 6153.035921096802, 21: 6583.0956292152405}

# %% [markdown]
# ## Save Model

# %%
# Save the Model
a2c_model_path = f"./models/a2c_custom_model_{env_id}_{training_time_max}.pth"
a2c_repo_path = f"a2c_custom_model_{env_id}_{training_time_max}.pth"
a2c_repo_path_metrics = f"a2c_custom_metrics_{env_id}_{training_time_max}.json"
torch.save(a2c_custom_model.state_dict(), a2c_model_path)

upload_file(
    path_or_fileobj=a2c_model_path,
    path_in_repo=a2c_repo_path,
    repo_id='maxstahl/a2c_pongnoframskip_v4_custom',
)

upload_file(
    path_or_fileobj=a2c_metrics_path,
    path_in_repo=a2c_repo_path_metrics,
    repo_id='maxstahl/a2c_pongnoframskip_v4_custom',
)
# Out:
# a2c_custom_model_PongNoFrameskip-v4_32400.pth:   0%|          | 0.00/6.76M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/maxstahl/a2c_pongnoframskip_v4_custom/commit/64c1da7d0fe24c06fa736bb04a81eaff701f33b9', commit_message='Upload a2c_custom_metrics_PongNoFrameskip-v4_32400.json with huggingface_hub', commit_description='', oid='64c1da7d0fe24c06fa736bb04a81eaff701f33b9', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# # DQN Implementation

# %% [markdown]
# ## Configurations

# %%
config_dict_dqn = {
    'device': 'cuda' if torch.cuda.is_available() else 'cpu',
    'gym_id': env_id,
    'total_timesteps': 1e7,
    'frame_skip': 4,
    'hidden_size': 512,
    'learning_rate': 1e-4,
    'gamma': 0.99,
    'buffer_size': 750000,        # Replay buffer size
    'batch_size': 32,             # Minibatch size for sampling
    'epsilon_start': 1.0,         # Initial epsilon for epsilon-greedy
    'epsilon_final': 0.01,        # Final epsilon
    'epsilon_decay': 1e6,         # Number of steps to decay epsilon
    'target_update_freq': 1000,   # Frequency (in steps) to update target network
    'train_freq': 4,              # Frequency (in steps) to train the network
    'learning_starts': 50000,     # Number of steps before starting training 
    'max_grad_norm': 0.5,         # Maximum gradient norm
    'time_limit': training_time_max,  
    'seed': seed
}

# Convert to Config Class
config_dqn = Config(config_dict_dqn)

# %% [markdown]
# ## Environment

# %%
env_dqn = make_env(config_dqn.gym_id, config_dqn.seed, config_dqn.frame_skip, clip_rewards=False)()

# %% [markdown]
# ## Neural Network

# %%
class DQNNetwork(nn.Module):
    def __init__(self, input_shape, n_actions, hidden_size=512):
        super().__init__()
        self.conv = nn.Sequential(
            layer_init(nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4)),
            nn.ReLU(),
            layer_init(nn.Conv2d(32, 64, kernel_size=4, stride=2)),
            nn.ReLU(),
            layer_init(nn.Conv2d(64, 64, kernel_size=3, stride=1)),
            nn.ReLU(),
        )
        conv_out_size = self._get_conv_out(input_shape)
        self.fc = nn.Sequential(
            layer_init(nn.Linear(conv_out_size, hidden_size)),
            nn.ReLU(),
            layer_init(nn.Linear(hidden_size, n_actions), std=0.01)
        )
      
    def _get_conv_out(self, shape):
        o = self.conv(torch.zeros(1, *shape))
        return int(np.prod(o.size()))
      
    def forward(self, x):
        x = x / 255.0  # Normalize pixel values
        x = self.conv(x)
        x = x.view(x.size(0), -1)
        return self.fc(x)

# %% [markdown]
# ## Replay Buffer

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
      
    def push(self, state, action, reward, next_state, done):
        # Store experience as a tuple
        self.buffer.append((state, action, reward, next_state, done))
      
    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        state, action, reward, next_state, done = map(np.array, zip(*batch))
        # Convert to appropriate types
        return (
            torch.tensor(state, dtype=torch.float32),
            torch.tensor(action, dtype=torch.long),
            torch.tensor(reward, dtype=torch.float32),
            torch.tensor(next_state, dtype=torch.float32),
            torch.tensor(done, dtype=torch.float32),
        )
      
    def __len__(self):
        return len(self.buffer)

# %% [markdown]
# ## Training

# %%
def train_dqn(config):
    device = torch.device(config.device)
    n_actions = env_dqn.action_space.n
    input_shape = env_dqn.observation_space.shape

    # Initialize networks
    policy_net = DQNNetwork(input_shape, n_actions, config.hidden_size).to(device)
    target_net = DQNNetwork(input_shape, n_actions, config.hidden_size).to(device)
    target_net.load_state_dict(policy_net.state_dict())
    target_net.eval()

    optimizer = optim.Adam(policy_net.parameters(), lr=config.learning_rate)

    # Initialize replay buffer with specified capacity
    replay_buffer = ReplayBuffer(int(config.buffer_size))

    # Metrics
    episode_rewards = []
    losses = []
    total_steps = 0
    total_episodes = 0

    # Counters for episodes and rewards since last print
    episodes_since_last_print = 0
    episode_rewards_since_last_print = []

    # Initialize time tracking variables
    start_time = time.time()
    episode_times = []  # Record the time when each episode ends
    loss_times = []     # Record the time when each loss is calculated
    threshold_times = {0: None, 10: None, 21: None}  # For convergence speed metric

    # Epsilon schedule function
    def epsilon_by_step(step):
        epsilon = config.epsilon_final + (config.epsilon_start - config.epsilon_final) * \
            max(0, (config.epsilon_decay - step) / config.epsilon_decay)
        return epsilon

    # Start training
    start_time = time.time()
    state, _ = env_dqn.reset()
    state = np.array(state)
    episode_reward = 0
    done = False

    while total_steps < config.total_timesteps:
        current_time = time.time()
        if current_time - start_time > config.time_limit:
            print("Time limit reached. Stopping training.")
            break

        epsilon = epsilon_by_step(total_steps)
        # Epsilon-greedy action selection
        if random.random() < epsilon:
            action = env_dqn.action_space.sample()
        else:
            with torch.no_grad():
                state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
                q_values = policy_net(state_tensor)
                action = q_values.argmax().item()
        
        next_state, reward, terminated, truncated, info = env_dqn.step(action)
        done = terminated or truncated
        episode_reward += reward
        total_steps += 1

        # Push experience to replay buffer
        replay_buffer.push(state, action, reward, next_state, done)
        state = np.array(next_state)

        # If done, reset the environment
        if done:
            episode_rewards.append(episode_reward)
            episode_rewards_since_last_print.append(episode_reward)

            # Record episode time
            elapsed_time = time.time() - start_time
            episode_times.append(elapsed_time)

            # Check convergence thresholds
            cumulative_reward = episode_reward
            for threshold in threshold_times:
                if cumulative_reward >= threshold and threshold_times[threshold] is None:
                    threshold_times[threshold] = elapsed_time

            episode_reward = 0
            total_episodes += 1
            episodes_since_last_print += 1
            state, _ = env_dqn.reset()
            state = np.array(state)

        # Start training only after collecting sufficient data
        if total_steps > config.learning_starts and total_steps % config.train_freq == 0:
            if len(replay_buffer) > config.batch_size:
                # Sample a batch
                batch_state, batch_action, batch_reward, batch_next_state, batch_done = replay_buffer.sample(config.batch_size)
                batch_state = batch_state.to(device)
                batch_action = batch_action.to(device)
                batch_reward = batch_reward.to(device)
                batch_next_state = batch_next_state.to(device)
                batch_done = batch_done.to(device)
                
                # Compute current Q values
                current_q_values = policy_net(batch_state).gather(1, batch_action.unsqueeze(1)).squeeze(1)
                
                # Compute target Q values using standard DQN logic
                with torch.no_grad():
                    next_q_values = target_net(batch_next_state).max(1)[0]
                    target_q_values = batch_reward + config.gamma * next_q_values * (1 - batch_done)
                
                # Compute loss
                loss = nn.functional.mse_loss(current_q_values, target_q_values)
                losses.append(loss.item())

                # Record time at loss calculation
                loss_times.append(time.time() - start_time)
                
                # Optimize the model
                optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(policy_net.parameters(), config.max_grad_norm)
                optimizer.step()

                # Update target network periodically
                if total_steps % config.target_update_freq == 0:
                    target_net.load_state_dict(policy_net.state_dict())
        
        # Print progress
        if total_steps % 10000 == 0:
            mean_reward = np.mean(episode_rewards[-10:]) if len(episode_rewards) >= 10 else np.mean(episode_rewards)
            if episodes_since_last_print > 0:
                mean_reward_last_episodes = np.mean(episode_rewards_since_last_print)
            else:
                mean_reward_last_episodes = 0
            print(f"Total Steps: {total_steps}, Episodes: {total_episodes}, Mean Reward total: {mean_reward:.2f}, Episodes since last print: {episodes_since_last_print}, Mean Reward Last Episodes: {mean_reward_last_episodes:.2f}")
            # Reset the counters
            episodes_since_last_print = 0
            episode_rewards_since_last_print = []

    total_training_time = time.time() - start_time
    timesteps_per_episode = total_steps / total_episodes if total_episodes > 0 else 0
    print("Training complete!")
    print(f"Total training time: {total_training_time:.2f} seconds")
    env_dqn.close()
    return policy_net, episode_rewards, total_training_time, losses, total_steps, total_episodes, timesteps_per_episode, episode_times, loss_times, threshold_times

# %%
dqn_custom_model, dqn_custom_episode_rewards, dqn_custom_total_training_time, dqn_custom_losses, dqn_custom_total_steps, dqn_custom_total_episodes, dqn_custom_timesteps_per_episode, dqn_episode_times, dqn_loss_times, dqn_threshold_times = train_dqn(config_dqn)
# Out:
# Total Steps: 10000, Episodes: 10, Mean Reward total: -20.40, Episodes since last print: 10, Mean Reward Last Episodes: -20.40
# Total Steps: 20000, Episodes: 21, Mean Reward total: -20.80, Episodes since last print: 11, Mean Reward Last Episodes: -20.73
# Total Steps: 30000, Episodes: 32, Mean Reward total: -20.20, Episodes since last print: 11, Mean Reward Last Episodes: -20.18
# Total Steps: 40000, Episodes: 43, Mean Reward total: -20.60, Episodes since last print: 11, Mean Reward Last Episodes: -20.64
# Total Steps: 50000, Episodes: 53, Mean Reward total: -19.70, Episodes since last print: 10, Mean Reward Last Episodes: -19.70
# Total Steps: 60000, Episodes: 65, Mean Reward total: -20.20, Episodes since last print: 12, Mean Reward Last Episodes: -20.17
# Total Steps: 70000, Episodes: 76, Mean Reward total: -20.40, Episodes since last print: 11, Mean Reward Last Episodes: -20.45
# Total Steps: 80000, Episodes: 86, Mean Reward total: -20.40, Episodes since last print: 10, Mean Reward Last Episodes: -20.40
# Total Steps: 90000, Episodes: 97, Mean Reward total: -19.70, Episodes since last print: 11, Mean Reward Last Episodes: -19.73
# Total Steps: 100000, Episodes: 108, Mean Reward total: -20.50, Episodes since last print: 11, Mean Reward Last Episodes: -20.55
# Total Steps: 110000, Episodes: 119, Mean Reward total: -20.20, Episodes since last print: 11, Mean Reward Last Episodes: -20.27
# Total Steps: 120000, Episodes: 129, Mean Reward total: -20.00, Episodes since last print: 10, Mean Reward Last Episodes: -20.00
# Total Steps: 130000, Episodes: 141, Mean Reward total: -20.60, Episodes since last print: 12, Mean Reward Last Episodes: -20.58
# Total Steps: 140000, Episodes: 151, Mean Reward total: -20.20, Episodes since last print: 10, Mean Reward Last Episodes: -20.20
# Total Steps: 150000, Episodes: 162, Mean Reward total: -19.80, Episodes since last print: 11, Mean Reward Last Episodes: -19.91
# Total Steps: 160000, Episodes: 172, Mean Reward total: -19.60, Episodes since last print: 10, Mean Reward Last Episodes: -19.60
# Total Steps: 170000, Episodes: 182, Mean Reward total: -19.80, Episodes since last print: 10, Mean Reward Last Episodes: -19.80
# Total Steps: 180000, Episodes: 192, Mean Reward total: -20.10, Episodes since last print: 10, Mean Reward Last Episodes: -20.10
# Total Steps: 190000, Episodes: 202, Mean Reward total: -19.60, Episodes since last print: 10, Mean Reward Last Episodes: -19.60
# Total Steps: 200000, Episodes: 211, Mean Reward total: -19.90, Episodes since last print: 9, Mean Reward Last Episodes: -19.89
# Total Steps: 210000, Episodes: 220, Mean Reward total: -19.20, Episodes since last print: 9, Mean Reward Last Episodes: -19.11
# Total Steps: 220000, Episodes: 229, Mean Reward total: -19.90, Episodes since last print: 9, Mean Reward Last Episodes: -19.89
# Total Steps: 230000, Episodes: 238, Mean Reward total: -19.50, Episodes since last print: 9, Mean Reward Last Episodes: -19.44
# Total Steps: 240000, Episodes: 246, Mean Reward total: -19.20, Episodes since last print: 8, Mean Reward Last Episodes: -19.25
# Total Steps: 250000, Episodes: 254, Mean Reward total: -18.70, Episodes since last print: 8, Mean Reward Last Episodes: -18.38
# Total Steps: 260000, Episodes: 263, Mean Reward total: -18.90, Episodes since last print: 9, Mean Reward Last Episodes: -19.00
# Total Steps: 270000, Episodes: 270, Mean Reward total: -18.50, Episodes since last print: 7, Mean Reward Last Episodes: -18.57
# Total Steps: 280000, Episodes: 279, Mean Reward total: -18.80, Episodes since last print: 9, Mean Reward Last Episodes: -18.78
# Total Steps: 290000, Episodes: 286, Mean Reward total: -19.00, Episodes since last print: 7, Mean Reward Last Episodes: -19.00
# Total Steps: 300000, Episodes: 294, Mean Reward total: -19.30, Episodes since last print: 8, Mean Reward Last Episodes: -19.38
# Total Steps: 310000, Episodes: 302, Mean Reward total: -18.90, Episodes since last print: 8, Mean Reward Last Episodes: -19.12
# Total Steps: 320000, Episodes: 309, Mean Reward total: -18.50, Episodes since last print: 7, Mean Reward Last Episodes: -18.00
# Total Steps: 330000, Episodes: 317, Mean Reward total: -18.90, Episodes since last print: 8, Mean Reward Last Episodes: -18.62
# Total Steps: 340000, Episodes: 324, Mean Reward total: -18.80, Episodes since last print: 7, Mean Reward Last Episodes: -18.86
# Total Steps: 350000, Episodes: 332, Mean Reward total: -19.10, Episodes since last print: 8, Mean Reward Last Episodes: -19.00
# Total Steps: 360000, Episodes: 339, Mean Reward total: -18.30, Episodes since last print: 7, Mean Reward Last Episodes: -18.43
# Total Steps: 370000, Episodes: 345, Mean Reward total: -18.10, Episodes since last print: 6, Mean Reward Last Episodes: -17.67
# Total Steps: 380000, Episodes: 352, Mean Reward total: -18.30, Episodes since last print: 7, Mean Reward Last Episodes: -18.29
# Total Steps: 390000, Episodes: 359, Mean Reward total: -19.20, Episodes since last print: 7, Mean Reward Last Episodes: -19.43
# Total Steps: 400000, Episodes: 366, Mean Reward total: -18.40, Episodes since last print: 7, Mean Reward Last Episodes: -18.14
# Total Steps: 410000, Episodes: 373, Mean Reward total: -18.20, Episodes since last print: 7, Mean Reward Last Episodes: -18.43
# Total Steps: 420000, Episodes: 380, Mean Reward total: -17.00, Episodes since last print: 7, Mean Reward Last Episodes: -17.00
# Total Steps: 430000, Episodes: 386, Mean Reward total: -16.70, Episodes since last print: 6, Mean Reward Last Episodes: -16.67
# Total Steps: 440000, Episodes: 391, Mean Reward total: -16.20, Episodes since last print: 5, Mean Reward Last Episodes: -15.80
# Total Steps: 450000, Episodes: 397, Mean Reward total: -16.70, Episodes since last print: 6, Mean Reward Last Episodes: -17.00
# Total Steps: 460000, Episodes: 404, Mean Reward total: -16.70, Episodes since last print: 7, Mean Reward Last Episodes: -16.71
# Total Steps: 470000, Episodes: 410, Mean Reward total: -17.70, Episodes since last print: 6, Mean Reward Last Episodes: -18.83
# Total Steps: 480000, Episodes: 417, Mean Reward total: -17.90, Episodes since last print: 7, Mean Reward Last Episodes: -17.57
# Total Steps: 490000, Episodes: 423, Mean Reward total: -17.30, Episodes since last print: 6, Mean Reward Last Episodes: -16.33
# Total Steps: 500000, Episodes: 428, Mean Reward total: -17.40, Episodes since last print: 5, Mean Reward Last Episodes: -17.80
# Total Steps: 510000, Episodes: 434, Mean Reward total: -15.80, Episodes since last print: 6, Mean Reward Last Episodes: -14.50
# Total Steps: 520000, Episodes: 441, Mean Reward total: -16.30, Episodes since last print: 7, Mean Reward Last Episodes: -17.43
# Total Steps: 530000, Episodes: 447, Mean Reward total: -16.90, Episodes since last print: 6, Mean Reward Last Episodes: -15.67
# Total Steps: 540000, Episodes: 452, Mean Reward total: -16.20, Episodes since last print: 5, Mean Reward Last Episodes: -16.80
# Total Steps: 550000, Episodes: 458, Mean Reward total: -15.60, Episodes since last print: 6, Mean Reward Last Episodes: -15.00
# Total Steps: 560000, Episodes: 464, Mean Reward total: -16.60, Episodes since last print: 6, Mean Reward Last Episodes: -17.00
# Total Steps: 570000, Episodes: 469, Mean Reward total: -16.20, Episodes since last print: 5, Mean Reward Last Episodes: -15.20
# Total Steps: 580000, Episodes: 475, Mean Reward total: -14.80, Episodes since last print: 6, Mean Reward Last Episodes: -14.83
# Total Steps: 590000, Episodes: 480, Mean Reward total: -15.40, Episodes since last print: 5, Mean Reward Last Episodes: -15.20
# Total Steps: 600000, Episodes: 486, Mean Reward total: -15.40, Episodes since last print: 6, Mean Reward Last Episodes: -15.50
# Total Steps: 610000, Episodes: 491, Mean Reward total: -14.40, Episodes since last print: 5, Mean Reward Last Episodes: -13.00
# Total Steps: 620000, Episodes: 495, Mean Reward total: -12.70, Episodes since last print: 4, Mean Reward Last Episodes: -12.00
# Total Steps: 630000, Episodes: 500, Mean Reward total: -12.50, Episodes since last print: 5, Mean Reward Last Episodes: -12.40
# Total Steps: 640000, Episodes: 505, Mean Reward total: -13.40, Episodes since last print: 5, Mean Reward Last Episodes: -14.40
# Total Steps: 650000, Episodes: 510, Mean Reward total: -13.30, Episodes since last print: 5, Mean Reward Last Episodes: -12.20
# Total Steps: 660000, Episodes: 515, Mean Reward total: -13.10, Episodes since last print: 5, Mean Reward Last Episodes: -14.00
# Total Steps: 670000, Episodes: 519, Mean Reward total: -12.50, Episodes since last print: 4, Mean Reward Last Episodes: -10.25
# Total Steps: 680000, Episodes: 523, Mean Reward total: -10.90, Episodes since last print: 4, Mean Reward Last Episodes: -10.25
# Total Steps: 690000, Episodes: 528, Mean Reward total: -10.70, Episodes since last print: 5, Mean Reward Last Episodes: -11.20
# Total Steps: 700000, Episodes: 532, Mean Reward total: -11.40, Episodes since last print: 4, Mean Reward Last Episodes: -10.50
# Total Steps: 710000, Episodes: 537, Mean Reward total: -9.80, Episodes since last print: 5, Mean Reward Last Episodes: -8.80
# Total Steps: 720000, Episodes: 541, Mean Reward total: -10.60, Episodes since last print: 4, Mean Reward Last Episodes: -11.50
# Total Steps: 730000, Episodes: 545, Mean Reward total: -9.70, Episodes since last print: 4, Mean Reward Last Episodes: -9.50
# Total Steps: 740000, Episodes: 550, Mean Reward total: -10.10, Episodes since last print: 5, Mean Reward Last Episodes: -10.40
# Total Steps: 750000, Episodes: 554, Mean Reward total: -9.00, Episodes since last print: 4, Mean Reward Last Episodes: -7.50
# Total Steps: 760000, Episodes: 558, Mean Reward total: -9.10, Episodes since last print: 4, Mean Reward Last Episodes: -9.00
# Total Steps: 770000, Episodes: 561, Mean Reward total: -8.20, Episodes since last print: 3, Mean Reward Last Episodes: -8.00
# Total Steps: 780000, Episodes: 565, Mean Reward total: -7.90, Episodes since last print: 4, Mean Reward Last Episodes: -6.00
# Total Steps: 790000, Episodes: 568, Mean Reward total: -6.40, Episodes since last print: 3, Mean Reward Last Episodes: -5.33
# Total Steps: 800000, Episodes: 573, Mean Reward total: -8.20, Episodes since last print: 5, Mean Reward Last Episodes: -10.80
# Total Steps: 810000, Episodes: 577, Mean Reward total: -8.60, Episodes since last print: 4, Mean Reward Last Episodes: -6.50
# Total Steps: 820000, Episodes: 580, Mean Reward total: -6.30, Episodes since last print: 3, Mean Reward Last Episodes: 0.00
# Total Steps: 830000, Episodes: 584, Mean Reward total: -3.20, Episodes since last print: 4, Mean Reward Last Episodes: -3.75
# Total Steps: 840000, Episodes: 587, Mean Reward total: -2.40, Episodes since last print: 3, Mean Reward Last Episodes: -3.00
# Total Steps: 850000, Episodes: 590, Mean Reward total: -4.60, Episodes since last print: 3, Mean Reward Last Episodes: -7.33
# Total Steps: 860000, Episodes: 594, Mean Reward total: -4.10, Episodes since last print: 4, Mean Reward Last Episodes: -2.50
# Total Steps: 870000, Episodes: 597, Mean Reward total: -6.30, Episodes since last print: 3, Mean Reward Last Episodes: -10.33
# Total Steps: 880000, Episodes: 600, Mean Reward total: -5.10, Episodes since last print: 3, Mean Reward Last Episodes: -3.33
# Total Steps: 890000, Episodes: 603, Mean Reward total: -3.90, Episodes since last print: 3, Mean Reward Last Episodes: 1.33
# Total Steps: 900000, Episodes: 607, Mean Reward total: -2.10, Episodes since last print: 4, Mean Reward Last Episodes: -3.75
# Total Steps: 910000, Episodes: 610, Mean Reward total: -1.10, Episodes since last print: 3, Mean Reward Last Episodes: 0.00
# Total Steps: 920000, Episodes: 614, Mean Reward total: -2.50, Episodes since last print: 4, Mean Reward Last Episodes: -4.00
# Total Steps: 930000, Episodes: 617, Mean Reward total: -1.10, Episodes since last print: 3, Mean Reward Last Episodes: 1.67
# Total Steps: 940000, Episodes: 620, Mean Reward total: -0.30, Episodes since last print: 3, Mean Reward Last Episodes: 2.67
# Total Steps: 950000, Episodes: 624, Mean Reward total: 1.50, Episodes since last print: 4, Mean Reward Last Episodes: 0.50
# Total Steps: 960000, Episodes: 627, Mean Reward total: 2.80, Episodes since last print: 3, Mean Reward Last Episodes: 6.00
# Total Steps: 970000, Episodes: 631, Mean Reward total: 2.30, Episodes since last print: 4, Mean Reward Last Episodes: -1.25
# Total Steps: 980000, Episodes: 634, Mean Reward total: 0.40, Episodes since last print: 3, Mean Reward Last Episodes: -3.00
# Total Steps: 990000, Episodes: 638, Mean Reward total: -0.20, Episodes since last print: 4, Mean Reward Last Episodes: 4.00
# Total Steps: 1000000, Episodes: 642, Mean Reward total: 2.80, Episodes since last print: 4, Mean Reward Last Episodes: 4.75
# Total Steps: 1010000, Episodes: 646, Mean Reward total: 4.90, Episodes since last print: 4, Mean Reward Last Episodes: 2.75
# Total Steps: 1020000, Episodes: 650, Mean Reward total: 4.60, Episodes since last print: 4, Mean Reward Last Episodes: 7.50
# Total Steps: 1030000, Episodes: 653, Mean Reward total: 7.30, Episodes since last print: 3, Mean Reward Last Episodes: 4.67
# Total Steps: 1040000, Episodes: 657, Mean Reward total: 6.00, Episodes since last print: 4, Mean Reward Last Episodes: 2.75
# Total Steps: 1050000, Episodes: 661, Mean Reward total: 6.90, Episodes since last print: 4, Mean Reward Last Episodes: 10.75
# Total Steps: 1060000, Episodes: 664, Mean Reward total: 6.00, Episodes since last print: 3, Mean Reward Last Episodes: 3.67
# Total Steps: 1070000, Episodes: 668, Mean Reward total: 8.10, Episodes since last print: 4, Mean Reward Last Episodes: 10.50
# Total Steps: 1080000, Episodes: 671, Mean Reward total: 8.60, Episodes since last print: 3, Mean Reward Last Episodes: 11.00
# Total Steps: 1090000, Episodes: 675, Mean Reward total: 10.50, Episodes since last print: 4, Mean Reward Last Episodes: 10.75
# Total Steps: 1100000, Episodes: 679, Mean Reward total: 10.90, Episodes since last print: 4, Mean Reward Last Episodes: 11.00
# Total Steps: 1110000, Episodes: 682, Mean Reward total: 9.50, Episodes since last print: 3, Mean Reward Last Episodes: 5.33
# Total Steps: 1120000, Episodes: 686, Mean Reward total: 9.80, Episodes since last print: 4, Mean Reward Last Episodes: 12.75
# Total Steps: 1130000, Episodes: 690, Mean Reward total: 9.00, Episodes since last print: 4, Mean Reward Last Episodes: 8.25
# Total Steps: 1140000, Episodes: 694, Mean Reward total: 8.60, Episodes since last print: 4, Mean Reward Last Episodes: 8.00
# Total Steps: 1150000, Episodes: 698, Mean Reward total: 10.60, Episodes since last print: 4, Mean Reward Last Episodes: 12.50
# Total Steps: 1160000, Episodes: 701, Mean Reward total: 9.60, Episodes since last print: 3, Mean Reward Last Episodes: 8.00
# Total Steps: 1170000, Episodes: 705, Mean Reward total: 9.90, Episodes since last print: 4, Mean Reward Last Episodes: 9.75
# Total Steps: 1180000, Episodes: 708, Mean Reward total: 9.10, Episodes since last print: 3, Mean Reward Last Episodes: 9.33
# Total Steps: 1190000, Episodes: 712, Mean Reward total: 11.70, Episodes since last print: 4, Mean Reward Last Episodes: 13.50
# Total Steps: 1200000, Episodes: 716, Mean Reward total: 11.50, Episodes since last print: 4, Mean Reward Last Episodes: 11.00
# Total Steps: 1210000, Episodes: 720, Mean Reward total: 10.80, Episodes since last print: 4, Mean Reward Last Episodes: 9.25
# Total Steps: 1220000, Episodes: 724, Mean Reward total: 12.40, Episodes since last print: 4, Mean Reward Last Episodes: 15.00
# Total Steps: 1230000, Episodes: 727, Mean Reward total: 11.30, Episodes since last print: 3, Mean Reward Last Episodes: 8.33
# Total Steps: 1240000, Episodes: 731, Mean Reward total: 11.10, Episodes since last print: 4, Mean Reward Last Episodes: 10.75
# Total Steps: 1250000, Episodes: 735, Mean Reward total: 11.10, Episodes since last print: 4, Mean Reward Last Episodes: 13.75
# Total Steps: 1260000, Episodes: 738, Mean Reward total: 12.30, Episodes since last print: 3, Mean Reward Last Episodes: 11.33
# Total Steps: 1270000, Episodes: 741, Mean Reward total: 10.60, Episodes since last print: 3, Mean Reward Last Episodes: 5.67
# Total Steps: 1280000, Episodes: 745, Mean Reward total: 9.70, Episodes since last print: 4, Mean Reward Last Episodes: 11.50
# Total Steps: 1290000, Episodes: 749, Mean Reward total: 9.10, Episodes since last print: 4, Mean Reward Last Episodes: 8.75
# Total Steps: 1300000, Episodes: 753, Mean Reward total: 9.70, Episodes since last print: 4, Mean Reward Last Episodes: 10.25
# Total Steps: 1310000, Episodes: 757, Mean Reward total: 11.20, Episodes since last print: 4, Mean Reward Last Episodes: 14.25
# Total Steps: 1320000, Episodes: 761, Mean Reward total: 13.10, Episodes since last print: 4, Mean Reward Last Episodes: 12.25
# Total Steps: 1330000, Episodes: 764, Mean Reward total: 12.50, Episodes since last print: 3, Mean Reward Last Episodes: 12.00
# Total Steps: 1340000, Episodes: 768, Mean Reward total: 11.60, Episodes since last print: 4, Mean Reward Last Episodes: 11.00
# Total Steps: 1350000, Episodes: 773, Mean Reward total: 9.50, Episodes since last print: 5, Mean Reward Last Episodes: 8.80
# Total Steps: 1360000, Episodes: 777, Mean Reward total: 12.90, Episodes since last print: 4, Mean Reward Last Episodes: 17.25
# Total Steps: 1370000, Episodes: 782, Mean Reward total: 15.50, Episodes since last print: 5, Mean Reward Last Episodes: 13.80
# Total Steps: 1380000, Episodes: 786, Mean Reward total: 14.00, Episodes since last print: 4, Mean Reward Last Episodes: 13.25
# Total Steps: 1390000, Episodes: 789, Mean Reward total: 10.30, Episodes since last print: 3, Mean Reward Last Episodes: 3.33
# Total Steps: 1400000, Episodes: 793, Mean Reward total: 9.50, Episodes since last print: 4, Mean Reward Last Episodes: 12.00
# Total Steps: 1410000, Episodes: 797, Mean Reward total: 11.80, Episodes since last print: 4, Mean Reward Last Episodes: 14.00
# Total Steps: 1420000, Episodes: 801, Mean Reward total: 13.30, Episodes since last print: 4, Mean Reward Last Episodes: 13.25
# Total Steps: 1430000, Episodes: 806, Mean Reward total: 14.60, Episodes since last print: 5, Mean Reward Last Episodes: 16.40
# Total Steps: 1440000, Episodes: 811, Mean Reward total: 15.80, Episodes since last print: 5, Mean Reward Last Episodes: 15.20
# Total Steps: 1450000, Episodes: 815, Mean Reward total: 15.30, Episodes since last print: 4, Mean Reward Last Episodes: 15.25
# Total Steps: 1460000, Episodes: 820, Mean Reward total: 15.20, Episodes since last print: 5, Mean Reward Last Episodes: 15.20
# Total Steps: 1470000, Episodes: 825, Mean Reward total: 16.10, Episodes since last print: 5, Mean Reward Last Episodes: 17.00
# Total Steps: 1480000, Episodes: 829, Mean Reward total: 15.60, Episodes since last print: 4, Mean Reward Last Episodes: 16.00
# Total Steps: 1490000, Episodes: 834, Mean Reward total: 16.70, Episodes since last print: 5, Mean Reward Last Episodes: 17.40
# Total Steps: 1500000, Episodes: 839, Mean Reward total: 17.80, Episodes since last print: 5, Mean Reward Last Episodes: 18.20
# Total Steps: 1510000, Episodes: 844, Mean Reward total: 16.90, Episodes since last print: 5, Mean Reward Last Episodes: 15.60
# Total Steps: 1520000, Episodes: 850, Mean Reward total: 17.50, Episodes since last print: 6, Mean Reward Last Episodes: 17.00
# Total Steps: 1530000, Episodes: 854, Mean Reward total: 17.20, Episodes since last print: 4, Mean Reward Last Episodes: 17.50
# Total Steps: 1540000, Episodes: 859, Mean Reward total: 17.60, Episodes since last print: 5, Mean Reward Last Episodes: 17.20
# Total Steps: 1550000, Episodes: 865, Mean Reward total: 14.40, Episodes since last print: 6, Mean Reward Last Episodes: 12.67
# Total Steps: 1560000, Episodes: 869, Mean Reward total: 14.00, Episodes since last print: 4, Mean Reward Last Episodes: 16.00
# Total Steps: 1570000, Episodes: 875, Mean Reward total: 17.70, Episodes since last print: 6, Mean Reward Last Episodes: 18.83
# Total Steps: 1580000, Episodes: 880, Mean Reward total: 18.30, Episodes since last print: 5, Mean Reward Last Episodes: 18.00
# Total Steps: 1590000, Episodes: 885, Mean Reward total: 17.20, Episodes since last print: 5, Mean Reward Last Episodes: 16.40
# Total Steps: 1600000, Episodes: 890, Mean Reward total: 17.60, Episodes since last print: 5, Mean Reward Last Episodes: 18.80
# Total Steps: 1610000, Episodes: 896, Mean Reward total: 19.00, Episodes since last print: 6, Mean Reward Last Episodes: 19.17
# Total Steps: 1620000, Episodes: 901, Mean Reward total: 18.70, Episodes since last print: 5, Mean Reward Last Episodes: 18.00
# Total Steps: 1630000, Episodes: 907, Mean Reward total: 19.50, Episodes since last print: 6, Mean Reward Last Episodes: 19.67
# Total Steps: 1640000, Episodes: 912, Mean Reward total: 19.60, Episodes since last print: 5, Mean Reward Last Episodes: 19.40
# Total Steps: 1650000, Episodes: 917, Mean Reward total: 19.10, Episodes since last print: 5, Mean Reward Last Episodes: 18.80
# Total Steps: 1660000, Episodes: 923, Mean Reward total: 19.10, Episodes since last print: 6, Mean Reward Last Episodes: 19.50
# Total Steps: 1670000, Episodes: 928, Mean Reward total: 18.60, Episodes since last print: 5, Mean Reward Last Episodes: 17.80
# Total Steps: 1680000, Episodes: 934, Mean Reward total: 18.70, Episodes since last print: 6, Mean Reward Last Episodes: 19.67
# Total Steps: 1690000, Episodes: 940, Mean Reward total: 19.30, Episodes since last print: 6, Mean Reward Last Episodes: 19.00
# Total Steps: 1700000, Episodes: 945, Mean Reward total: 19.10, Episodes since last print: 5, Mean Reward Last Episodes: 19.20
# Total Steps: 1710000, Episodes: 950, Mean Reward total: 18.60, Episodes since last print: 5, Mean Reward Last Episodes: 18.00
# Total Steps: 1720000, Episodes: 956, Mean Reward total: 18.70, Episodes since last print: 6, Mean Reward Last Episodes: 19.17
# Total Steps: 1730000, Episodes: 962, Mean Reward total: 19.80, Episodes since last print: 6, Mean Reward Last Episodes: 20.17
# Total Steps: 1740000, Episodes: 967, Mean Reward total: 18.80, Episodes since last print: 5, Mean Reward Last Episodes: 17.60
# Total Steps: 1750000, Episodes: 972, Mean Reward total: 18.80, Episodes since last print: 5, Mean Reward Last Episodes: 20.00
# Total Steps: 1760000, Episodes: 978, Mean Reward total: 20.00, Episodes since last print: 6, Mean Reward Last Episodes: 20.00
# Total Steps: 1770000, Episodes: 983, Mean Reward total: 19.50, Episodes since last print: 5, Mean Reward Last Episodes: 19.00
# Total Steps: 1780000, Episodes: 989, Mean Reward total: 19.40, Episodes since last print: 6, Mean Reward Last Episodes: 19.83
# Total Steps: 1790000, Episodes: 994, Mean Reward total: 19.60, Episodes since last print: 5, Mean Reward Last Episodes: 19.20
# Total Steps: 1800000, Episodes: 1000, Mean Reward total: 18.90, Episodes since last print: 6, Mean Reward Last Episodes: 18.67
# Total Steps: 1810000, Episodes: 1005, Mean Reward total: 19.10, Episodes since last print: 5, Mean Reward Last Episodes: 19.20
# Total Steps: 1820000, Episodes: 1011, Mean Reward total: 19.00, Episodes since last print: 6, Mean Reward Last Episodes: 19.00
# Total Steps: 1830000, Episodes: 1016, Mean Reward total: 19.40, Episodes since last print: 5, Mean Reward Last Episodes: 20.00
# Total Steps: 1840000, Episodes: 1022, Mean Reward total: 19.40, Episodes since last print: 6, Mean Reward Last Episodes: 19.00
# Total Steps: 1850000, Episodes: 1027, Mean Reward total: 19.20, Episodes since last print: 5, Mean Reward Last Episodes: 19.00
# Total Steps: 1860000, Episodes: 1033, Mean Reward total: 19.50, Episodes since last print: 6, Mean Reward Last Episodes: 19.83
# Total Steps: 1870000, Episodes: 1039, Mean Reward total: 19.70, Episodes since last print: 6, Mean Reward Last Episodes: 19.50
# Total Steps: 1880000, Episodes: 1044, Mean Reward total: 18.90, Episodes since last print: 5, Mean Reward Last Episodes: 18.20
# Total Steps: 1890000, Episodes: 1050, Mean Reward total: 18.90, Episodes since last print: 6, Mean Reward Last Episodes: 19.50
# Total Steps: 1900000, Episodes: 1055, Mean Reward total: 19.60, Episodes since last print: 5, Mean Reward Last Episodes: 19.80
# Total Steps: 1910000, Episodes: 1061, Mean Reward total: 18.90, Episodes since last print: 6, Mean Reward Last Episodes: 18.33
# Total Steps: 1920000, Episodes: 1066, Mean Reward total: 18.90, Episodes since last print: 5, Mean Reward Last Episodes: 19.00
# Total Steps: 1930000, Episodes: 1072, Mean Reward total: 19.00, Episodes since last print: 6, Mean Reward Last Episodes: 19.00
# Total Steps: 1940000, Episodes: 1077, Mean Reward total: 19.10, Episodes since last print: 5, Mean Reward Last Episodes: 19.40
# Total Steps: 1950000, Episodes: 1083, Mean Reward total: 19.60, Episodes since last print: 6, Mean Reward Last Episodes: 19.83
# Total Steps: 1960000, Episodes: 1088, Mean Reward total: 19.40, Episodes since last print: 5, Mean Reward Last Episodes: 18.80
# Total Steps: 1970000, Episodes: 1094, Mean Reward total: 18.90, Episodes since last print: 6, Mean Reward Last Episodes: 18.83
# Total Steps: 1980000, Episodes: 1099, Mean Reward total: 19.00, Episodes since last print: 5, Mean Reward Last Episodes: 19.40
# Total Steps: 1990000, Episodes: 1105, Mean Reward total: 19.60, Episodes since last print: 6, Mean Reward Last Episodes: 19.33
# Total Steps: 2000000, Episodes: 1111, Mean Reward total: 19.50, Episodes since last print: 6, Mean Reward Last Episodes: 19.50
# Total Steps: 2010000, Episodes: 1116, Mean Reward total: 19.30, Episodes since last print: 5, Mean Reward Last Episodes: 19.20
# Total Steps: 2020000, Episodes: 1122, Mean Reward total: 20.00, Episodes since last print: 6, Mean Reward Last Episodes: 20.50
# Total Steps: 2030000, Episodes: 1127, Mean Reward total: 20.00, Episodes since last print: 5, Mean Reward Last Episodes: 19.60
# Total Steps: 2040000, Episodes: 1133, Mean Reward total: 19.70, Episodes since last print: 6, Mean Reward Last Episodes: 19.83
# Total Steps: 2050000, Episodes: 1139, Mean Reward total: 19.80, Episodes since last print: 6, Mean Reward Last Episodes: 19.67
# Total Steps: 2060000, Episodes: 1144, Mean Reward total: 19.10, Episodes since last print: 5, Mean Reward Last Episodes: 18.60
# Total Steps: 2070000, Episodes: 1150, Mean Reward total: 18.70, Episodes since last print: 6, Mean Reward Last Episodes: 18.33
# Total Steps: 2080000, Episodes: 1155, Mean Reward total: 20.10, Episodes since last print: 5, Mean Reward Last Episodes: 20.20
# Total Steps: 2090000, Episodes: 1161, Mean Reward total: 20.00, Episodes since last print: 6, Mean Reward Last Episodes: 19.67
# Total Steps: 2100000, Episodes: 1167, Mean Reward total: 19.80, Episodes since last print: 6, Mean Reward Last Episodes: 19.67
# Total Steps: 2110000, Episodes: 1172, Mean Reward total: 19.50, Episodes since last print: 5, Mean Reward Last Episodes: 19.40
# Total Steps: 2120000, Episodes: 1178, Mean Reward total: 19.20, Episodes since last print: 6, Mean Reward Last Episodes: 19.17
# Total Steps: 2130000, Episodes: 1183, Mean Reward total: 19.40, Episodes since last print: 5, Mean Reward Last Episodes: 19.60
# Total Steps: 2140000, Episodes: 1189, Mean Reward total: 20.10, Episodes since last print: 6, Mean Reward Last Episodes: 20.50
# Total Steps: 2150000, Episodes: 1195, Mean Reward total: 19.50, Episodes since last print: 6, Mean Reward Last Episodes: 19.00
# Time limit reached. Stopping training.
# Training complete!
# Total training time: 32400.04 seconds

# %% [markdown]
# ## Evaluation

# %%
def evaluate_model_dqn(model, config, num_episodes=10):
    env = gym.make(config.gym_id, render_mode='rgb_array', frameskip=1)
    env = AtariWrappers(env, config.frame_skip)
    env.reset(seed=config.seed)
    env.action_space.seed(config.seed)
    model.eval()
    device = torch.device(config.device)

    total_rewards = []
    for episode in range(num_episodes):
        state, _ = env.reset()
        state = np.array(state)
        done = False
        episode_reward = 0
        while not done:
            with torch.no_grad():
                state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
                q_values = model(state_tensor)
                action = q_values.argmax().item()
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            episode_reward += reward
            state = np.array(next_state)
        total_rewards.append(episode_reward)
    mean_reward = np.mean(total_rewards)
    std_reward = np.std(total_rewards)
    env.close()
    model.train()
    return mean_reward, std_reward

# %%
dqn_custom_mean_reward, dqn_custom_std_reward = evaluate_model_dqn(dqn_custom_model, config_dqn)
print(f"DQN Evaluation over 10 episodes: Mean Reward = {dqn_custom_mean_reward}, Std Reward = {dqn_custom_std_reward}")
# Out:
# DQN Evaluation over 10 episodes: Mean Reward = 18.7, Std Reward = 0.45825756949558394

# %% [markdown]
# ## Metrics

# %%
results_dqn = {
  'Episode Rewards': dqn_custom_episode_rewards,
  'Episode Times': dqn_episode_times,
  'Losses': dqn_custom_losses,
  'Loss Times': dqn_loss_times,
  'Threshold Times': dqn_threshold_times,
  'Total Training Time': dqn_custom_total_training_time,
  'Total Steps': dqn_custom_total_steps,
  'Total Episodes': dqn_custom_total_episodes,
  'Timesteps per Episode': dqn_custom_timesteps_per_episode,
  'Mean Evaluation Reward': dqn_custom_mean_reward,
  'Std Evaluation Reward': dqn_custom_std_reward
}

dqn_metrics_path = f"./metrics/dqn_custom_metrics_{env_id}_{training_time_max}.json"
with open(dqn_metrics_path, 'w') as f:
  json.dump(results_dqn, f)

# Print Summary
print("=== Training Summary ===")
print(f"Total Training Time: {dqn_custom_total_training_time:.2f} seconds")
print(f"Total Steps: {dqn_custom_total_steps}")
print(f"Total Episodes: {dqn_custom_total_episodes}")
print(f"Average Timesteps per Episode: {dqn_custom_timesteps_per_episode:.2f}")
print(f"Final Mean Reward (last 10 episodes): {np.mean(dqn_custom_episode_rewards[-10:]):.2f}")
print(f"Evaluation Mean Reward: {dqn_custom_mean_reward:.2f}")
print(f"Evaluation Std Reward: {dqn_custom_std_reward:.2f}")
print(f"Threshold Times: {dqn_threshold_times}")
# Out:
# === Training Summary ===
# Total Training Time: 32400.04 seconds
# Total Steps: 2155108
# Total Episodes: 1197
# Average Timesteps per Episode: 1800.42
# Final Mean Reward (last 10 episodes): 19.40
# Evaluation Mean Reward: 18.70
# Evaluation Std Reward: 0.46
# Threshold Times: {0: 11609.60074019432, 10: 13503.442669153214, 21: 21429.59261894226}

# %% [markdown]
# ## Save Model

# %%
# Save the Model
dqn_model_path = f"./models/dqn_custom_model_{env_id}_{training_time_max}.pth"
dqn_repo_path = f"dqn_custom_model_{env_id}_{training_time_max}.pth"
dqn_repo_path_metrics = f"dqn_custom_metrics_{env_id}_{training_time_max}.json"
torch.save(dqn_custom_model.state_dict(), dqn_model_path)

upload_file(
    path_or_fileobj=dqn_model_path,
    path_in_repo=dqn_repo_path,
    repo_id='maxstahl/dqn_pongnoframskip_v4_custom',
)

upload_file(
    path_or_fileobj=dqn_metrics_path,
    path_in_repo=dqn_repo_path_metrics,
    repo_id='maxstahl/dqn_pongnoframskip_v4_custom',
)
# Out:
# dqn_custom_model_PongNoFrameskip-v4_32400.pth:   0%|          | 0.00/6.75M [00:00<?, ?B/s]
# dqn_custom_metrics_PongNoFrameskip-v4_32400.json:   0%|          | 0.00/22.0M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/maxstahl/dqn_pongnoframskip_v4_custom/commit/ef9ca69ce65b767da4cccabfda335e754790218d', commit_message='Upload dqn_custom_metrics_PongNoFrameskip-v4_32400.json with huggingface_hub', commit_description='', oid='ef9ca69ce65b767da4cccabfda335e754790218d', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# # Summary

# %%
summary_data = {
  'Model': ['PPO', 'A2C', 'DQN'],
  'Mean Reward': [ppo_custom_mean_reward, a2c_custom_mean_reward, dqn_custom_mean_reward],
  'Std Reward': [ppo_custom_std_reward, a2c_custom_std_reward, dqn_custom_std_reward],
  'Training Time (s)': [ppo_custom_total_training_time, a2c_custom_total_training_time, dqn_custom_total_training_time],
  'Total Steps': [ppo_custom_total_steps, a2c_custom_total_steps, dqn_custom_total_steps],
  'Total Episodes': [ppo_custom_total_episodes, a2c_custom_total_episodes, dqn_custom_total_episodes],
  'Timesteps per Episode': [ppo_custom_timesteps_per_episode, a2c_custom_timesteps_per_episode, dqn_custom_timesteps_per_episode]
}

summary_df = pd.DataFrame(summary_data)

display(summary_df)
# Out:
#   Model  Mean Reward  Std Reward  Training Time (s)  Total Steps  \
# 0   PPO         19.5    1.688194       32401.683105      8514560
# 1   A2C         20.7    0.900000       32400.472499     27022336
# 2   DQN         18.7    0.458258       32400.043806      2155108
#
#    Total Episodes  Timesteps per Episode
# 0            4074            2089.975454
# 1           12929            2090.056153
# 2            1197            1800.424394
